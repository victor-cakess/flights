# %%
import os
import re
import logging
import requests
from bs4 import BeautifulSoup
import logging
from urllib.parse import urljoin
from concurrent.futures import ThreadPoolExecutor
import os
import csv
import chardet
import logging
import shutil
import polars as pl
import glob
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine, Table, MetaData
import logging

# %%
BASE_URL = "https://siros.anac.gov.br/siros/registros/diversos/vra/"
SAVE_DIR = "hydrogen"

# %% [markdown]
# # Overview
#
# This script automates the process of scraping CSV flight data files from a website that organizes its content in year directories. Basically, it does the grunt work of fetching, filtering, and downloading CSV files so you don’t have to click around like a caveman.
#
# ## What it does
#
# - **Logging setup:**
#   Sets up logging with timestamps and levels. If things go wrong—or even if they go right—you'll know exactly when the drama unfolded.
#
# - **Link extraction:**
#   Fetches all hyperlinks from a webpage, then uses smart filtering to isolate year-based directories and csv file links.
#
# - **Parallel downloads:**
#   Leverages a thread pool (up to 4 threads) to download csv files concurrently. Because who has time to wait for downloads to finish one at a time?
#
# ## Why it does it
#
# This code saves you from manual labor and the tedium of clicking through endless pages. It ensures that your csv files are neatly organized and downloaded in record time, so you can focus on the real work—like analyzing data.
#
# In short: automate the tedious parts and get on with the important stuff.

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[logging.StreamHandler()]
)

def get_links(url: str) -> list:
    resp = requests.get(url)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, 'html.parser')
    links = [urljoin(url, a['href']) for a in soup.find_all('a', href=True)]
    return links

def get_year_links(base_url: str) -> list:
    all_links = get_links(base_url)
    year_links = [link for link in all_links if link.rstrip('/').split('/')[-1].isdigit()]
    logging.info(f"Found {len(year_links)} year directory link(s): {year_links}")
    return year_links

def get_csv_links(year_url: str) -> list:
    all_links = get_links(year_url)
    csv_links = [link for link in all_links if link.lower().endswith('.csv')]
    logging.debug(f"Found {len(csv_links)} CSV file(s) in {year_url}")
    return csv_links

def download_csv(csv_url: str, csv_path: str) -> None:
    """
    Download a CSV file from csv_url to csv_path on disk.
    Used as the 'target' for executor.submit(...) calls.
    """
    logging.info(f"Downloading {csv_url} -> {csv_path}")
    resp = requests.get(csv_url, stream=True)
    resp.raise_for_status()
    with open(csv_path, 'wb') as f:
        for chunk in resp.iter_content(chunk_size=8192):
            f.write(chunk)
    logging.debug(f"Finished downloading {csv_url}")

def scrape_flights(base_url: str, save_dir: str) -> None:
    """
    Main function:
      1. Fetch year directories
      2. For each year, fetch CSV links
      3. Use ThreadPoolExecutor to download CSVs in parallel
    """
    if not os.path.exists(save_dir):
        os.makedirs(save_dir, exist_ok=True)
        logging.info(f"Created main directory: {save_dir}")

    year_links = get_year_links(base_url)

    # Create a thread pool with up to 4 concurrent threads
    with ThreadPoolExecutor(max_workers=4) as executor:
        for year_link in year_links:
            year = year_link.rstrip('/').split('/')[-1]
            csv_links = get_csv_links(year_link)

            for csv_link in csv_links:
                csv_name = csv_link.split('/')[-1]
                # Optionally prepend the year to avoid collisions:
                # csv_name = f"{year}_{csv_name}"

                csv_path = os.path.join(save_dir, csv_name)
                # Submit each download to the thread pool
                executor.submit(download_csv, csv_link, csv_path)

    logging.info("All files downloaded successfully.")

# %%
scrape_flights(BASE_URL, SAVE_DIR)
# Out:
# 2025-03-02 15:23:49,157 [INFO] Created main directory: hydrogen
# 2025-03-02 15:23:49,416 [INFO] Found 26 year directory link(s): ['https://siros.anac.gov.br/siros/registros/diversos/vra/2000/', 'https://siros.anac.gov.br/siros/registros/diversos/vra/
[INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2023/VRA_2023_06.csv -> hydrogen/VRA_2023_06.csv
# 2025-03-02 15:52:04,042 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2023/VRA_2023_07.csv -> hydrogen/VRA_2023_07.csv
# 2025-03-02 15:52:11,622 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2023/VRA_2023_08.csv -> hydrogen/VRA_2023_08.csv
# 2025-03-02 15:52:25,647 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2023/VRA_2023_09.csv -> hydrogen/VRA_2023_09.csv
# 2025-03-02 15:52:50,452 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2023/VRA_2023_10.csv -> hydrogen/VRA_2023_10.csv
# 2025-03-02 15:52:52,214 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2023/VRA_2023_11.csv -> hydrogen/VRA_2023_11.csv
# 2025-03-02 15:53:08,996 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2023/VRA_2023_12.csv -> hydrogen/VRA_2023_12.csv
# 2025-03-02 15:53:17,373 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_01.csv -> hydrogen/VRA_2024_01.csv
# 2025-03-02 15:53:24,390 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_02.csv -> hydrogen/VRA_2024_02.csv
# 2025-03-02 15:53:39,739 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_03.csv -> hydrogen/VRA_2024_03.csv
# 2025-03-02 15:53:50,871 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_04.csv -> hydrogen/VRA_2024_04.csv
# 2025-03-02 15:54:06,159 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_05.csv -> hydrogen/VRA_2024_05.csv
# 2025-03-02 15:54:07,111 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_06.csv -> hydrogen/VRA_2024_06.csv
# 2025-03-02 15:54:13,608 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_07.csv -> hydrogen/VRA_2024_07.csv
# 2025-03-02 15:54:31,637 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_08.csv -> hydrogen/VRA_2024_08.csv
# 2025-03-02 15:54:44,865 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_09.csv -> hydrogen/VRA_2024_09.csv
# 2025-03-02 15:54:46,983 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_10.csv -> hydrogen/VRA_2024_10.csv
# 2025-03-02 15:55:07,506 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_11.csv -> hydrogen/VRA_2024_11.csv
# 2025-03-02 15:55:10,608 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2024/VRA_2024_12.csv -> hydrogen/VRA_2024_12.csv
# 2025-03-02 15:55:28,473 [INFO] Downloading https://siros.anac.gov.br/siros/registros/diversos/vra/2025/VRA_2025_01.csv -> hydrogen/VRA_2025_01.csv
# 2025-03-02 15:56:09,648 [INFO] All files downloaded successfully.

# %% [markdown]
# # Overview
#
# This script converts CSV files into a standardized format by detecting their original encoding and delimiter, then rewriting them as UTF-8 files with semicolon delimiters. Basically, it does the heavy lifting of cleaning up messy CSVs so you don’t have to spend your day playing detective with file formats.
#
# ## What it does
#
# - **Encoding detection:**
#   Reads a chunk of each file in binary mode and uses chardet to guess the file’s encoding. If it can’t figure it out, it defaults to UTF-8—because sometimes even computers need a fallback plan.
#
# - **Delimiter detection:**
#   Samples the file in text mode and employs csv.sniffer to identify the correct delimiter. If the sniffer fails, it defaults to a comma.
#
# - **File conversion:**
#   Streams the CSV content row by row from the source file, using the detected settings, and writes it to a new file with forced UTF-8 encoding and semicolon delimiters. This streaming approach keeps memory usage in check, even for huge files.
#
# - **Batch processing:**
#   Iterates over a folder of CSV files, converting each one and logging every success and misstep along the way.
#
# ## Why it does it
#
# This code saves you from the nightmare of dealing with CSV files in every possible flavor of encoding and delimiter. It standardizes your data, making it ready for analysis without the hassle of manual cleanup.

# %%
def detect_file_encoding(file_path, read_bytes=65536):
    """
    Detect the encoding of a file by reading up to `read_bytes` from it in binary mode.
    Falls back to 'utf-8' if detection is inconclusive.
    """
    with open(file_path, 'rb') as rb:
        raw_data = rb.read(read_bytes)
        detect_result = chardet.detect(raw_data)
        detected = detect_result.get("encoding")
        if not detected:
            logging.warning(f"Could not detect encoding for {file_path}; defaulting to 'utf-8'")
            return "utf-8"
        return detected

def detect_file_delimiter(file_path, encoding, possible_delimiters=[",",";","\t","|"], read_chars=8192):
    """
    Detect the delimiter by reading up to `read_chars` from the file in text mode (with `encoding`).
    Falls back to ',' if Sniffer fails.
    """
    with open(file_path, "r", encoding=encoding, errors="replace") as f:
        sample = f.read(read_chars)
    try:
        dialect = csv.Sniffer().sniff(sample, delimiters=possible_delimiters)
        return dialect.delimiter
    except csv.Error:
        logging.warning(f"Could not sniff delimiter for {file_path}; defaulting to ','")
        return ","

def convert_single_csv(
    source_path, target_path,
    force_delimiter=";", force_encoding="utf-8",
    chunk_size=8192
):
    """
    Reads the CSV at `source_path` with detected encoding/delimiter
    and writes it to `target_path` in `force_encoding` & `force_delimiter`.
    
    Uses a streaming approach so we don't load entire files into memory.
    """
    # 1) Detect encoding
    detected_encoding = detect_file_encoding(source_path)
    # 2) Detect delimiter
    detected_delimiter = detect_file_delimiter(source_path, detected_encoding)

    logging.info(
        f"Converting '{source_path}' | Detected Encoding='{detected_encoding}' "
        f"Delimiter='{detected_delimiter}' -> {target_path} (utf-8 / ';')"
    )

    # 3) Stream read + write
    with open(source_path, "r", encoding=detected_encoding, errors="replace") as csv_in, \
         open(target_path, "w", encoding=force_encoding, newline="") as csv_out:

        reader = csv.reader(csv_in, delimiter=detected_delimiter)
        writer = csv.writer(csv_out, delimiter=force_delimiter)

        for row in reader:
            writer.writerow(row)

def convert_csvs_to_utf8_semicolon(
    source_folder="hydrogen",
    target_folder="helium"
):
    """
    1. Iterates over .csv files in `source_folder`.
    2. Detects encoding/delimiter for each file.
    3. Streams the data out to `target_folder` as UTF-8 / ';' delimiter.
    """
    if not os.path.exists(target_folder):
        os.makedirs(target_folder, exist_ok=True)
        logging.info(f"Created target folder: {target_folder}")

    files_processed = 0
    for filename in os.listdir(source_folder):
        if filename.lower().endswith(".csv"):
            source_path = os.path.join(source_folder, filename)
            target_path = os.path.join(target_folder, filename)

            try:
                convert_single_csv(
                    source_path=source_path,
                    target_path=target_path,
                    force_delimiter=";",
                    force_encoding="utf-8"
                )
                files_processed += 1
            except Exception as e:
                logging.error(f"Failed to convert {filename}: {e}")

    logging.info(f"Conversion complete. {files_processed} file(s) processed.")

# %%
logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")

convert_csvs_to_utf8_semicolon(source_folder="hydrogen", target_folder="helium")
# Out:
# 2025-03-02 16:20:48,072 [INFO] Created target folder: helium
# 2025-03-02 16:20:48,186 [INFO] Converting 'hydrogen/VRA_20072.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20072.csv (utf-8 / ';')
# 2025-03-02 16:20:48,294 [INFO] Converting 'hydrogen/VRA_2023_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_02.csv (utf-8 / ';')
# 2025-03-02 16:20:48,670 [INFO] Converting 'hydrogen/VRA_200311.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200311.csv (utf-8 / ';')
# 2025-03-02 16:20:48,757 [INFO] Converting 'hydrogen/VRA_2010_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_06.csv (utf-8 / ';')
# 2025-03-02 16:20:49,122 [INFO] Converting 'hydrogen/VRA_2024_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_04.csv (utf-8 / ';')
# 2025-03-02 16:20:49,435 [INFO] Converting 'hydrogen/VRA_2014_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_09.csv (utf-8 / ';')
# 2025-03-02 16:20:49,858 [INFO] Converting 'hydrogen/VRA_2016_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_10.csv (utf-8 / ';')
# 2025-03-02 16:20:50,287 [INFO] Converting 'hydrogen/VRA_20004.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20004.csv (utf-8 / ';')
# 2025-03-02 16:20:50,482 [INFO] Converting 'hydrogen/VRA_20046.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20046.csv (utf-8 / ';')
# 2025-03-02 16:20:50,573 [INFO] Converting 'hydrogen/VRA_2022_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_04.csv (utf-8 / ';')
# 2025-03-02 16:20:50,923 [INFO] Converting 'hydrogen/VRA_20075.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20075.csv (utf-8 / ';')
# 2025-03-02 16:20:51,040 [INFO] Converting 'hydrogen/VRA_2020_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_02.csv (utf-8 / ';')
# 2025-03-02 16:20:51,378 [INFO] Converting 'hydrogen/VRA_2010_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_02.csv (utf-8 / ';')
# 2025-03-02 16:20:51,805 [INFO] Converting 'hydrogen/VRA_20048.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20048.csv (utf-8 / ';')
# 2025-03-02 16:20:51,994 [INFO] Converting 'hydrogen/VRA_20092.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20092.csv (utf-8 / ';')
# 2025-03-02 16:20:52,105 [INFO] Converting 'hydrogen/VRA_2014_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_05.csv (utf-8 / ';')
# 2025-03-02 16:20:52,538 [INFO] Converting 'hydrogen/VRA_2017_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_10.csv (utf-8 / ';')
# 2025-03-02 16:20:52,896 [INFO] Converting 'hydrogen/VRA_2020_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_11.csv (utf-8 / ';')
# 2025-03-02 16:20:53,076 [INFO] Converting 'hydrogen/VRA_2018_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_02.csv (utf-8 / ';')
# 2025-03-02 16:20:53,425 [INFO] Converting 'hydrogen/VRA_2014_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_03.csv (utf-8 / ';')
# 2025-03-02 16:20:53,859 [INFO] Converting 'hydrogen/VRA_2017_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_09.csv (utf-8 / ';')
# 2025-03-02 16:20:54,291 [INFO] Converting 'hydrogen/VRA_200010.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200010.csv (utf-8 / ';')
# 2025-03-02 16:20:54,394 [INFO] Converting 'hydrogen/VRA_2021_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_10.csv (utf-8 / ';')
# 2025-03-02 16:20:54,726 [INFO] Converting 'hydrogen/VRA_20096.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20096.csv (utf-8 / ';')
# 2025-03-02 16:20:54,834 [INFO] Converting 'hydrogen/VRA_2017_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_12.csv (utf-8 / ';')
# 2025-03-02 16:20:55,215 [INFO] Converting 'hydrogen/VRA_2018_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_12.csv (utf-8 / ';')
# 2025-03-02 16:20:55,573 [INFO] Converting 'hydrogen/VRA_2011_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_03.csv (utf-8 / ';')
# 2025-03-02 16:20:55,993 [INFO] Converting 'hydrogen/VRA_2013_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_04.csv (utf-8 / ';')
# 2025-03-02 16:20:56,402 [INFO] Converting 'hydrogen/VRA_2013_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_07.csv (utf-8 / ';')
# 2025-03-02 16:20:56,844 [INFO] Converting 'hydrogen/VRA_2017_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_11.csv (utf-8 / ';')
# 2025-03-02 16:20:57,196 [INFO] Converting 'hydrogen/VRA_2019_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_05.csv (utf-8 / ';')
# 2025-03-02 16:20:57,509 [INFO] Converting 'hydrogen/VRA_2011_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_04.csv (utf-8 / ';')
# 2025-03-02 16:20:58,009 [INFO] Converting 'hydrogen/VRA_20019.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20019.csv (utf-8 / ';')
# 2025-03-02 16:20:58,112 [INFO] Converting 'hydrogen/VRA_2012_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_03.csv (utf-8 / ';')
# 2025-03-02 16:20:58,575 [INFO] Converting 'hydrogen/VRA_2013_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_10.csv (utf-8 / ';')
# 2025-03-02 16:20:59,084 [INFO] Converting 'hydrogen/VRA_20032.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20032.csv (utf-8 / ';')
# 2025-03-02 16:20:59,186 [INFO] Converting 'hydrogen/VRA_2015_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_11.csv (utf-8 / ';')
# 2025-03-02 16:20:59,676 [INFO] Converting 'hydrogen/VRA_20074.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20074.csv (utf-8 / ';')
# 2025-03-02 16:20:59,786 [INFO] Converting 'hydrogen/VRA_2011_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_08.csv (utf-8 / ';')
# 2025-03-02 16:21:00,223 [INFO] Converting 'hydrogen/VRA_2019_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_01.csv (utf-8 / ';')
# 2025-03-02 16:21:00,592 [INFO] Converting 'hydrogen/VRA_2023_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_10.csv (utf-8 / ';')
# 2025-03-02 16:21:00,997 [INFO] Converting 'hydrogen/VRA_20082.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20082.csv (utf-8 / ';')
# 2025-03-02 16:21:01,100 [INFO] Converting 'hydrogen/VRA_2015_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_07.csv (utf-8 / ';')
# 2025-03-02 16:21:01,658 [INFO] Converting 'hydrogen/VRA_20057.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20057.csv (utf-8 / ';')
# 2025-03-02 16:21:01,848 [INFO] Converting 'hydrogen/VRA_200910.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200910.csv (utf-8 / ';')
# 2025-03-02 16:21:01,967 [INFO] Converting 'hydrogen/VRA_2017_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_04.csv (utf-8 / ';')
# 2025-03-02 16:21:02,381 [INFO] Converting 'hydrogen/VRA_200510.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200510.csv (utf-8 / ';')
# 2025-03-02 16:21:02,479 [INFO] Converting 'hydrogen/VRA_2022_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_07.csv (utf-8 / ';')
# 2025-03-02 16:21:02,782 [INFO] Converting 'hydrogen/VRA_2017_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_07.csv (utf-8 / ';')
# 2025-03-02 16:21:03,144 [INFO] Converting 'hydrogen/VRA_2020_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_12.csv (utf-8 / ';')
# 2025-03-02 16:21:03,445 [INFO] Converting 'hydrogen/VRA_200810.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200810.csv (utf-8 / ';')
# 2025-03-02 16:21:03,545 [INFO] Converting 'hydrogen/VRA_2020_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_03.csv (utf-8 / ';')
# 2025-03-02 16:21:03,894 [INFO] Converting 'hydrogen/VRA_20063.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20063.csv (utf-8 / ';')
# 2025-03-02 16:21:04,080 [INFO] Converting 'hydrogen/VRA_20077.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20077.csv (utf-8 / ';')
# 2025-03-02 16:21:04,286 [INFO] Converting 'hydrogen/VRA_20067.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20067.csv (utf-8 / ';')
# 2025-03-02 16:21:04,480 [INFO] Converting 'hydrogen/VRA_200012.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200012.csv (utf-8 / ';')
# 2025-03-02 16:21:04,584 [INFO] Converting 'hydrogen/VRA_2024_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_05.csv (utf-8 / ';')
# 2025-03-02 16:21:04,890 [INFO] Converting 'hydrogen/VRA_2017_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_03.csv (utf-8 / ';')
# 2025-03-02 16:21:05,240 [INFO] Converting 'hydrogen/VRA_2010_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_03.csv (utf-8 / ';')
# 2025-03-02 16:21:05,606 [INFO] Converting 'hydrogen/VRA_2018_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_04.csv (utf-8 / ';')
# 2025-03-02 16:21:05,923 [INFO] Converting 'hydrogen/VRA_2012_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_08.csv (utf-8 / ';')
# 2025-03-02 16:21:06,362 [INFO] Converting 'hydrogen/VRA_2017_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_01.csv (utf-8 / ';')
# 2025-03-02 16:21:06,821 [INFO] Converting 'hydrogen/VRA_20034.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20034.csv (utf-8 / ';')
# 2025-03-02 16:21:06,932 [INFO] Converting 'hydrogen/VRA_2023_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_03.csv (utf-8 / ';')
# 2025-03-02 16:21:07,243 [INFO] Converting 'hydrogen/VRA_2010_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_04.csv (utf-8 / ';')
# 2025-03-02 16:21:07,592 [INFO] Converting 'hydrogen/VRA_2012_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_01.csv (utf-8 / ';')
# 2025-03-02 16:21:08,065 [INFO] Converting 'hydrogen/VRA_2011_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_02.csv (utf-8 / ';')
# 2025-03-02 16:21:08,539 [INFO] Converting 'hydrogen/VRA_20001.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20001.csv (utf-8 / ';')
# 2025-03-02 16:21:08,653 [INFO] Converting 'hydrogen/VRA_2018_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_03.csv (utf-8 / ';')
# 2025-03-02 16:21:08,939 [INFO] Converting 'hydrogen/VRA_2024_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_12.csv (utf-8 / ';')
# 2025-03-02 16:21:09,269 [INFO] Converting 'hydrogen/VRA_2016_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_08.csv (utf-8 / ';')
# 2025-03-02 16:21:09,617 [INFO] Converting 'hydrogen/VRA_2023_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_04.csv (utf-8 / ';')
# 2025-03-02 16:21:09,913 [INFO] Converting 'hydrogen/VRA_2018_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_05.csv (utf-8 / ';')
# 2025-03-02 16:21:10,347 [INFO] Converting 'hydrogen/VRA_20002.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20002.csv (utf-8 / ';')
# 2025-03-02 16:21:10,452 [INFO] Converting 'hydrogen/VRA_2024_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_01.csv (utf-8 / ';')
# 2025-03-02 16:21:10,877 [INFO] Converting 'hydrogen/VRA_200210.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200210.csv (utf-8 / ';')
# 2025-03-02 16:21:10,988 [INFO] Converting 'hydrogen/VRA_2019_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_03.csv (utf-8 / ';')
# 2025-03-02 16:21:11,323 [INFO] Converting 'hydrogen/VRA_2016_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_06.csv (utf-8 / ';')
# 2025-03-02 16:21:11,670 [INFO] Converting 'hydrogen/VRA_2020_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_08.csv (utf-8 / ';')
# 2025-03-02 16:21:11,777 [INFO] Converting 'hydrogen/VRA_2016_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_05.csv (utf-8 / ';')
# 2025-03-02 16:21:12,131 [INFO] Converting 'hydrogen/VRA_2020_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_10.csv (utf-8 / ';')
# 2025-03-02 16:21:12,387 [INFO] Converting 'hydrogen/VRA_20094.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20094.csv (utf-8 / ';')
# 2025-03-02 16:21:12,496 [INFO] Converting 'hydrogen/VRA_2024_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_11.csv (utf-8 / ';')
# 2025-03-02 16:21:12,804 [INFO] Converting 'hydrogen/VRA_2011_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_11.csv (utf-8 / ';')
# 2025-03-02 16:21:13,232 [INFO] Converting 'hydrogen/VRA_2012_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_05.csv (utf-8 / ';')
# 2025-03-02 16:21:13,687 [INFO] Converting 'hydrogen/VRA_2012_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_07.csv (utf-8 / ';')
# 2025-03-02 16:21:14,147 [INFO] Converting 'hydrogen/VRA_2016_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_01.csv (utf-8 / ';')
# 2025-03-02 16:21:14,679 [INFO] Converting 'hydrogen/VRA_20014.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20014.csv (utf-8 / ';')
# 2025-03-02 16:21:14,786 [INFO] Converting 'hydrogen/VRA_2013_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_11.csv (utf-8 / ';')
# 2025-03-02 16:21:15,208 [INFO] Converting 'hydrogen/VRA_2024_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_03.csv (utf-8 / ';')
# 2025-03-02 16:21:15,523 [INFO] Converting 'hydrogen/VRA_2010_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_11.csv (utf-8 / ';')
# 2025-03-02 16:21:16,012 [INFO] Converting 'hydrogen/VRA_200111.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200111.csv (utf-8 / ';')
# 2025-03-02 16:21:16,123 [INFO] Converting 'hydrogen/VRA_2022_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_08.csv (utf-8 / ';')
# 2025-03-02 16:21:16,504 [INFO] Converting 'hydrogen/VRA_20049.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20049.csv (utf-8 / ';')
# 2025-03-02 16:21:16,597 [INFO] Converting 'hydrogen/VRA_2021_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_04.csv (utf-8 / ';')
# 2025-03-02 16:21:16,724 [INFO] Converting 'hydrogen/VRA_2013_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_06.csv (utf-8 / ';')
# 2025-03-02 16:21:17,232 [INFO] Converting 'hydrogen/VRA_20035.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20035.csv (utf-8 / ';')
# 2025-03-02 16:21:17,330 [INFO] Converting 'hydrogen/VRA_2020_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_01.csv (utf-8 / ';')
# 2025-03-02 16:21:17,789 [INFO] Converting 'hydrogen/VRA_20024.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20024.csv (utf-8 / ';')
# 2025-03-02 16:21:17,899 [INFO] Converting 'hydrogen/VRA_2015_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_02.csv (utf-8 / ';')
# 2025-03-02 16:21:18,414 [INFO] Converting 'hydrogen/VRA_20058.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20058.csv (utf-8 / ';')
# 2025-03-02 16:21:18,512 [INFO] Converting 'hydrogen/VRA_2021_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_12.csv (utf-8 / ';')
# 2025-03-02 16:21:18,801 [INFO] Converting 'hydrogen/VRA_2021_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_01.csv (utf-8 / ';')
# 2025-03-02 16:21:19,131 [INFO] Converting 'hydrogen/VRA_200412.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200412.csv (utf-8 / ';')
# 2025-03-02 16:21:19,320 [INFO] Converting 'hydrogen/VRA_20076.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20076.csv (utf-8 / ';')
# 2025-03-02 16:21:19,435 [INFO] Converting 'hydrogen/VRA_2019_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_02.csv (utf-8 / ';')
# 2025-03-02 16:21:19,863 [INFO] Converting 'hydrogen/VRA_20011.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20011.csv (utf-8 / ';')
# 2025-03-02 16:21:20,067 [INFO] Converting 'hydrogen/VRA_20064.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20064.csv (utf-8 / ';')
# 2025-03-02 16:21:20,171 [INFO] Converting 'hydrogen/VRA_2021_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_03.csv (utf-8 / ';')
# 2025-03-02 16:21:20,339 [INFO] Converting 'hydrogen/VRA_2022_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_11.csv (utf-8 / ';')
# 2025-03-02 16:21:20,733 [INFO] Converting 'hydrogen/VRA_20006.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20006.csv (utf-8 / ';')
# 2025-03-02 16:21:20,834 [INFO] Converting 'hydrogen/VRA_2011_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_05.csv (utf-8 / ';')
# 2025-03-02 16:21:21,268 [INFO] Converting 'hydrogen/VRA_2021_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_07.csv (utf-8 / ';')
# 2025-03-02 16:21:21,572 [INFO] Converting 'hydrogen/VRA_20088.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20088.csv (utf-8 / ';')
# 2025-03-02 16:21:21,768 [INFO] Converting 'hydrogen/VRA_200011.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200011.csv (utf-8 / ';')
# 2025-03-02 16:21:21,960 [INFO] Converting 'hydrogen/VRA_200911.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200911.csv (utf-8 / ';')
# 2025-03-02 16:21:22,168 [INFO] Converting 'hydrogen/VRA_200912.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200912.csv (utf-8 / ';')
# 2025-03-02 16:21:22,309 [INFO] Converting 'hydrogen/VRA_2020_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_06.csv (utf-8 / ';')
# 2025-03-02 16:21:22,373 [INFO] Converting 'hydrogen/VRA_2012_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_09.csv (utf-8 / ';')
# 2025-03-02 16:21:22,887 [INFO] Converting 'hydrogen/VRA_20042.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20042.csv (utf-8 / ';')
# 2025-03-02 16:21:22,971 [INFO] Converting 'hydrogen/VRA_2013_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_03.csv (utf-8 / ';')
# 2025-03-02 16:21:23,405 [INFO] Converting 'hydrogen/VRA_2024_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_02.csv (utf-8 / ';')
# 2025-03-02 16:21:23,720 [INFO] Converting 'hydrogen/VRA_2019_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_11.csv (utf-8 / ';')
# 2025-03-02 16:21:24,056 [INFO] Converting 'hydrogen/VRA_2014_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_08.csv (utf-8 / ';')
# 2025-03-02 16:21:24,583 [INFO] Converting 'hydrogen/VRA_20047.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20047.csv (utf-8 / ';')
# 2025-03-02 16:21:24,776 [INFO] Converting 'hydrogen/VRA_20069.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20069.csv (utf-8 / ';')
# 2025-03-02 16:21:24,964 [INFO] Converting 'hydrogen/VRA_20052.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20052.csv (utf-8 / ';')
# 2025-03-02 16:21:25,051 [INFO] Converting 'hydrogen/VRA_2020_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_07.csv (utf-8 / ';')
# 2025-03-02 16:21:25,143 [INFO] Converting 'hydrogen/VRA_2022_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_01.csv (utf-8 / ';')
# 2025-03-02 16:21:25,436 [INFO] Converting 'hydrogen/VRA_2011_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_12.csv (utf-8 / ';')
# 2025-03-02 16:21:25,996 [INFO] Converting 'hydrogen/VRA_20038.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20038.csv (utf-8 / ';')
# 2025-03-02 16:21:26,067 [INFO] Converting 'hydrogen/VRA_2014_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_06.csv (utf-8 / ';')
# 2025-03-02 16:21:26,084 [INFO] Converting 'hydrogen/VRA_2014_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_11.csv (utf-8 / ';')
# 2025-03-02 16:21:26,517 [INFO] Converting 'hydrogen/VRA_2017_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_05.csv (utf-8 / ';')
# 2025-03-02 16:21:26,960 [INFO] Converting 'hydrogen/VRA_20095.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20095.csv (utf-8 / ';')
# 2025-03-02 16:21:27,163 [INFO] Converting 'hydrogen/VRA_200112.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200112.csv (utf-8 / ';')
# 2025-03-02 16:21:27,277 [INFO] Converting 'hydrogen/VRA_2012_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_04.csv (utf-8 / ';')
# 2025-03-02 16:21:27,725 [INFO] Converting 'hydrogen/VRA_2016_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_11.csv (utf-8 / ';')
# 2025-03-02 16:21:28,153 [INFO] Converting 'hydrogen/VRA_20009.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20009.csv (utf-8 / ';')
# 2025-03-02 16:21:28,256 [INFO] Converting 'hydrogen/VRA_2023_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_09.csv (utf-8 / ';')
# 2025-03-02 16:21:28,572 [INFO] Converting 'hydrogen/VRA_2022_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_03.csv (utf-8 / ';')
# 2025-03-02 16:21:28,838 [INFO] Converting 'hydrogen/VRA_2010_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_07.csv (utf-8 / ';')
# 2025-03-02 16:21:29,232 [INFO] Converting 'hydrogen/VRA_2022_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_09.csv (utf-8 / ';')
# 2025-03-02 16:21:29,612 [INFO] Converting 'hydrogen/VRA_200512.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200512.csv (utf-8 / ';')
# 2025-03-02 16:21:29,713 [INFO] Converting 'hydrogen/VRA_2017_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_02.csv (utf-8 / ';')
# 2025-03-02 16:21:30,045 [INFO] Converting 'hydrogen/VRA_2022_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_10.csv (utf-8 / ';')
# 2025-03-02 16:21:30,351 [INFO] Converting 'hydrogen/VRA_2010_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_05.csv (utf-8 / ';')
# 2025-03-02 16:21:30,815 [INFO] Converting 'hydrogen/VRA_20066.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20066.csv (utf-8 / ';')
# 2025-03-02 16:21:31,012 [INFO] Converting 'hydrogen/VRA_20013.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20013.csv (utf-8 / ';')
# 2025-03-02 16:21:31,216 [INFO] Converting 'hydrogen/VRA_200411.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200411.csv (utf-8 / ';')
# 2025-03-02 16:21:31,304 [INFO] Converting 'hydrogen/VRA_2015_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_09.csv (utf-8 / ';')
# 2025-03-02 16:21:31,758 [INFO] Converting 'hydrogen/VRA_2010_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_08.csv (utf-8 / ';')
# 2025-03-02 16:21:32,245 [INFO] Converting 'hydrogen/VRA_200410.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200410.csv (utf-8 / ';')
# 2025-03-02 16:21:32,433 [INFO] Converting 'hydrogen/VRA_20097.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20097.csv (utf-8 / ';')
# 2025-03-02 16:21:32,552 [INFO] Converting 'hydrogen/VRA_2024_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_08.csv (utf-8 / ';')
# 2025-03-02 16:21:32,982 [INFO] Converting 'hydrogen/VRA_20087.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20087.csv (utf-8 / ';')
# 2025-03-02 16:21:33,097 [INFO] Converting 'hydrogen/VRA_2022_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_05.csv (utf-8 / ';')
# 2025-03-02 16:21:33,385 [INFO] Converting 'hydrogen/VRA_2011_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_06.csv (utf-8 / ';')
# 2025-03-02 16:21:33,815 [INFO] Converting 'hydrogen/VRA_2016_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_07.csv (utf-8 / ';')
# 2025-03-02 16:21:34,172 [INFO] Converting 'hydrogen/VRA_2015_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_06.csv (utf-8 / ';')
# 2025-03-02 16:21:34,706 [INFO] Converting 'hydrogen/VRA_200312.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200312.csv (utf-8 / ';')
# 2025-03-02 16:21:34,799 [INFO] Converting 'hydrogen/VRA_2023_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_08.csv (utf-8 / ';')
# 2025-03-02 16:21:35,134 [INFO] Converting 'hydrogen/VRA_2022_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_12.csv (utf-8 / ';')
# 2025-03-02 16:21:35,555 [INFO] Converting 'hydrogen/VRA_20086.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20086.csv (utf-8 / ';')
# 2025-03-02 16:21:35,756 [INFO] Converting 'hydrogen/VRA_20061.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20061.csv (utf-8 / ';')
# 2025-03-02 16:21:35,951 [INFO] Converting 'hydrogen/VRA_20079.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20079.csv (utf-8 / ';')
# 2025-03-02 16:21:36,064 [INFO] Converting 'hydrogen/VRA_2011_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_01.csv (utf-8 / ';')
# 2025-03-02 16:21:36,497 [INFO] Converting 'hydrogen/VRA_2019_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_04.csv (utf-8 / ';')
# 2025-03-02 16:21:36,920 [INFO] Converting 'hydrogen/VRA_20091.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20091.csv (utf-8 / ';')
# 2025-03-02 16:21:37,035 [INFO] Converting 'hydrogen/VRA_2010_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_10.csv (utf-8 / ';')
# 2025-03-02 16:21:37,446 [INFO] Converting 'hydrogen/VRA_2021_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_06.csv (utf-8 / ';')
# 2025-03-02 16:21:37,714 [INFO] Converting 'hydrogen/VRA_20045.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20045.csv (utf-8 / ';')
# 2025-03-02 16:21:37,897 [INFO] Converting 'hydrogen/VRA_20054.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20054.csv (utf-8 / ';')
# 2025-03-02 16:21:38,082 [INFO] Converting 'hydrogen/VRA_20062.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20062.csv (utf-8 / ';')
# 2025-03-02 16:21:38,159 [INFO] Converting 'hydrogen/VRA_2014_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_07.csv (utf-8 / ';')
# 2025-03-02 16:21:38,272 [INFO] Converting 'hydrogen/VRA_20033.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20033.csv (utf-8 / ';')
# 2025-03-02 16:21:38,387 [INFO] Converting 'hydrogen/VRA_2011_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_10.csv (utf-8 / ';')
# 2025-03-02 16:21:38,919 [INFO] Converting 'hydrogen/VRA_200610.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200610.csv (utf-8 / ';')
# 2025-03-02 16:21:39,024 [INFO] Converting 'hydrogen/VRA_2023_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_11.csv (utf-8 / ';')
# 2025-03-02 16:21:39,427 [INFO] Converting 'hydrogen/VRA_20044.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20044.csv (utf-8 / ';')
# 2025-03-02 16:21:39,517 [INFO] Converting 'hydrogen/VRA_2019_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_10.csv (utf-8 / ';')
# 2025-03-02 16:21:39,860 [INFO] Converting 'hydrogen/VRA_2020_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_09.csv (utf-8 / ';')
# 2025-03-02 16:21:39,990 [INFO] Converting 'hydrogen/VRA_2020_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_05.csv (utf-8 / ';')
# 2025-03-02 16:21:40,043 [INFO] Converting 'hydrogen/VRA_2014_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_12.csv (utf-8 / ';')
# 2025-03-02 16:21:40,514 [INFO] Converting 'hydrogen/VRA_2019_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_07.csv (utf-8 / ';')
# 2025-03-02 16:21:40,868 [INFO] Converting 'hydrogen/VRA_2017_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_08.csv (utf-8 / ';')
# 2025-03-02 16:21:41,226 [INFO] Converting 'hydrogen/VRA_2015_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_10.csv (utf-8 / ';')
# 2025-03-02 16:21:41,654 [INFO] Converting 'hydrogen/VRA_2019_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_06.csv (utf-8 / ';')
# 2025-03-02 16:21:41,970 [INFO] Converting 'hydrogen/VRA_2021_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_02.csv (utf-8 / ';')
# 2025-03-02 16:21:42,155 [INFO] Converting 'hydrogen/VRA_2013_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_05.csv (utf-8 / ';')
# 2025-03-02 16:21:42,594 [INFO] Converting 'hydrogen/VRA_2023_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_05.csv (utf-8 / ';')
# 2025-03-02 16:21:42,998 [INFO] Converting 'hydrogen/VRA_20039.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20039.csv (utf-8 / ';')
# 2025-03-02 16:21:43,083 [INFO] Converting 'hydrogen/VRA_2021_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_11.csv (utf-8 / ';')
# 2025-03-02 16:21:43,436 [INFO] Converting 'hydrogen/VRA_20007.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20007.csv (utf-8 / ';')
# 2025-03-02 16:21:43,637 [INFO] Converting 'hydrogen/VRA_20027.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20027.csv (utf-8 / ';')
# 2025-03-02 16:21:43,843 [INFO] Converting 'hydrogen/VRA_20037.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20037.csv (utf-8 / ';')
# 2025-03-02 16:21:44,021 [INFO] Converting 'hydrogen/VRA_20031.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20031.csv (utf-8 / ';')
# 2025-03-02 16:21:44,135 [INFO] Converting 'hydrogen/VRA_2018_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_08.csv (utf-8 / ';')
# 2025-03-02 16:21:44,580 [INFO] Converting 'hydrogen/VRA_20099.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20099.csv (utf-8 / ';')
# 2025-03-02 16:21:44,693 [INFO] Converting 'hydrogen/VRA_2018_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_01.csv (utf-8 / ';')
# 2025-03-02 16:21:45,095 [INFO] Converting 'hydrogen/VRA_2023_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_12.csv (utf-8 / ';')
# 2025-03-02 16:21:45,422 [INFO] Converting 'hydrogen/VRA_2021_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_08.csv (utf-8 / ';')
# 2025-03-02 16:21:45,743 [INFO] Converting 'hydrogen/VRA_20017.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20017.csv (utf-8 / ';')
# 2025-03-02 16:21:45,860 [INFO] Converting 'hydrogen/VRA_2015_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_08.csv (utf-8 / ';')
# 2025-03-02 16:21:46,309 [INFO] Converting 'hydrogen/VRA_2012_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_06.csv (utf-8 / ';')
# 2025-03-02 16:21:46,756 [INFO] Converting 'hydrogen/VRA_2011_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_07.csv (utf-8 / ';')
# 2025-03-02 16:21:47,208 [INFO] Converting 'hydrogen/VRA_2014_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_02.csv (utf-8 / ';')
# 2025-03-02 16:21:47,695 [INFO] Converting 'hydrogen/VRA_20018.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20018.csv (utf-8 / ';')
# 2025-03-02 16:21:47,894 [INFO] Converting 'hydrogen/VRA_20016.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20016.csv (utf-8 / ';')
# 2025-03-02 16:21:48,005 [INFO] Converting 'hydrogen/VRA_2021_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_09.csv (utf-8 / ';')
# 2025-03-02 16:21:48,234 [INFO] Converting 'hydrogen/VRA_2021_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2021_05.csv (utf-8 / ';')
# 2025-03-02 16:21:48,388 [INFO] Converting 'hydrogen/VRA_2015_05.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_05.csv (utf-8 / ';')
# 2025-03-02 16:21:48,837 [INFO] Converting 'hydrogen/VRA_2016_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_03.csv (utf-8 / ';')
# 2025-03-02 16:21:49,246 [INFO] Converting 'hydrogen/VRA_2018_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_07.csv (utf-8 / ';')
# 2025-03-02 16:21:49,616 [INFO] Converting 'hydrogen/VRA_2013_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_12.csv (utf-8 / ';')
# 2025-03-02 16:21:50,080 [INFO] Converting 'hydrogen/VRA_2016_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_09.csv (utf-8 / ';')
# 2025-03-02 16:21:50,417 [INFO] Converting 'hydrogen/VRA_2019_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_08.csv (utf-8 / ';')
# 2025-03-02 16:21:50,840 [INFO] Converting 'hydrogen/VRA_20068.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20068.csv (utf-8 / ';')
# 2025-03-02 16:21:51,039 [INFO] Converting 'hydrogen/VRA_20065.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20065.csv (utf-8 / ';')
# 2025-03-02 16:21:51,235 [INFO] Converting 'hydrogen/VRA_20081.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20081.csv (utf-8 / ';')
# 2025-03-02 16:21:51,442 [INFO] Converting 'hydrogen/VRA_20073.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20073.csv (utf-8 / ';')
# 2025-03-02 16:21:51,555 [INFO] Converting 'hydrogen/VRA_2013_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_09.csv (utf-8 / ';')
# 2025-03-02 16:21:51,968 [INFO] Converting 'hydrogen/VRA_2014_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_01.csv (utf-8 / ';')
# 2025-03-02 16:21:52,528 [INFO] Converting 'hydrogen/VRA_200110.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200110.csv (utf-8 / ';')
# 2025-03-02 16:21:52,645 [INFO] Converting 'hydrogen/VRA_2010_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_12.csv (utf-8 / ';')
# 2025-03-02 16:21:53,187 [INFO] Converting 'hydrogen/VRA_20085.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20085.csv (utf-8 / ';')
# 2025-03-02 16:21:53,392 [INFO] Converting 'hydrogen/VRA_20015.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20015.csv (utf-8 / ';')
# 2025-03-02 16:21:53,600 [INFO] Converting 'hydrogen/VRA_20084.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20084.csv (utf-8 / ';')
# 2025-03-02 16:21:53,710 [INFO] Converting 'hydrogen/VRA_2024_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_09.csv (utf-8 / ';')
# 2025-03-02 16:21:54,127 [INFO] Converting 'hydrogen/VRA_20041.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20041.csv (utf-8 / ';')
# 2025-03-02 16:21:54,313 [INFO] Converting 'hydrogen/VRA_20025.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20025.csv (utf-8 / ';')
# 2025-03-02 16:21:54,526 [INFO] Converting 'hydrogen/VRA_200812.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200812.csv (utf-8 / ';')
# 2025-03-02 16:21:54,640 [INFO] Converting 'hydrogen/VRA_2015_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_12.csv (utf-8 / ';')
# 2025-03-02 16:21:55,163 [INFO] Converting 'hydrogen/VRA_20089.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20089.csv (utf-8 / ';')
# 2025-03-02 16:21:55,363 [INFO] Converting 'hydrogen/VRA_20071.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20071.csv (utf-8 / ';')
# 2025-03-02 16:21:55,486 [INFO] Converting 'hydrogen/VRA_2024_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_10.csv (utf-8 / ';')
# 2025-03-02 16:21:55,819 [INFO] Converting 'hydrogen/VRA_2023_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_07.csv (utf-8 / ';')
# 2025-03-02 16:21:56,160 [INFO] Converting 'hydrogen/VRA_2013_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_02.csv (utf-8 / ';')
# 2025-03-02 16:21:56,662 [INFO] Converting 'hydrogen/VRA_20003.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20003.csv (utf-8 / ';')
# 2025-03-02 16:21:56,872 [INFO] Converting 'hydrogen/VRA_20083.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20083.csv (utf-8 / ';')
# 2025-03-02 16:21:57,080 [INFO] Converting 'hydrogen/VRA_200712.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200712.csv (utf-8 / ';')
# 2025-03-02 16:21:57,198 [INFO] Converting 'hydrogen/VRA_2018_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_10.csv (utf-8 / ';')
# 2025-03-02 16:21:57,537 [INFO] Converting 'hydrogen/VRA_2023_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_01.csv (utf-8 / ';')
# 2025-03-02 16:21:57,879 [INFO] Converting 'hydrogen/VRA_2011_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2011_09.csv (utf-8 / ';')
# 2025-03-02 16:21:58,316 [INFO] Converting 'hydrogen/VRA_2025_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2025_01.csv (utf-8 / ';')
# 2025-03-02 16:21:58,760 [INFO] Converting 'hydrogen/VRA_200212.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200212.csv (utf-8 / ';')
# 2025-03-02 16:21:58,876 [INFO] Converting 'hydrogen/VRA_2020_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2020_04.csv (utf-8 / ';')
# 2025-03-02 16:21:59,019 [INFO] Converting 'hydrogen/VRA_20028.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20028.csv (utf-8 / ';')
# 2025-03-02 16:21:59,224 [INFO] Converting 'hydrogen/VRA_20022.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20022.csv (utf-8 / ';')
# 2025-03-02 16:21:59,421 [INFO] Converting 'hydrogen/VRA_20008.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20008.csv (utf-8 / ';')
# 2025-03-02 16:21:59,533 [INFO] Converting 'hydrogen/VRA_2013_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_01.csv (utf-8 / ';')
# 2025-03-02 16:22:00,090 [INFO] Converting 'hydrogen/VRA_20093.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20093.csv (utf-8 / ';')
# 2025-03-02 16:22:00,294 [INFO] Converting 'hydrogen/VRA_20029.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20029.csv (utf-8 / ';')
# 2025-03-02 16:22:00,499 [INFO] Converting 'hydrogen/VRA_20098.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20098.csv (utf-8 / ';')
# 2025-03-02 16:22:00,714 [INFO] Converting 'hydrogen/VRA_20055.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20055.csv (utf-8 / ';')
# 2025-03-02 16:22:00,907 [INFO] Converting 'hydrogen/VRA_20005.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20005.csv (utf-8 / ';')
# 2025-03-02 16:22:01,006 [INFO] Converting 'hydrogen/VRA_2024_07.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_07.csv (utf-8 / ';')
# 2025-03-02 16:22:01,445 [INFO] Converting 'hydrogen/VRA_200511.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200511.csv (utf-8 / ';')
# 2025-03-02 16:22:01,545 [INFO] Converting 'hydrogen/VRA_2015_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_01.csv (utf-8 / ';')
# 2025-03-02 16:22:02,033 [INFO] Converting 'hydrogen/VRA_2013_08.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2013_08.csv (utf-8 / ';')
# 2025-03-02 16:22:02,563 [INFO] Converting 'hydrogen/VRA_20021.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20021.csv (utf-8 / ';')
# 2025-03-02 16:22:02,779 [INFO] Converting 'hydrogen/VRA_200310.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200310.csv (utf-8 / ';')
# 2025-03-02 16:22:02,967 [INFO] Converting 'hydrogen/VRA_20043.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20043.csv (utf-8 / ';')
# 2025-03-02 16:22:03,158 [INFO] Converting 'hydrogen/VRA_20053.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20053.csv (utf-8 / ';')
# 2025-03-02 16:22:03,254 [INFO] Converting 'hydrogen/VRA_2024_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2024_06.csv (utf-8 / ';')
# 2025-03-02 16:22:03,564 [INFO] Converting 'hydrogen/VRA_2017_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2017_06.csv (utf-8 / ';')
# 2025-03-02 16:22:03,997 [INFO] Converting 'hydrogen/VRA_20078.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20078.csv (utf-8 / ';')
# 2025-03-02 16:22:04,202 [INFO] Converting 'hydrogen/VRA_20023.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20023.csv (utf-8 / ';')
# 2025-03-02 16:22:04,320 [INFO] Converting 'hydrogen/VRA_2016_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_02.csv (utf-8 / ';')
# 2025-03-02 16:22:04,757 [INFO] Converting 'hydrogen/VRA_2019_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_09.csv (utf-8 / ';')
# 2025-03-02 16:22:05,097 [INFO] Converting 'hydrogen/VRA_2015_03.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_03.csv (utf-8 / ';')
# 2025-03-02 16:22:05,568 [INFO] Converting 'hydrogen/VRA_2018_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_11.csv (utf-8 / ';')
# 2025-03-02 16:22:05,900 [INFO] Converting 'hydrogen/VRA_2023_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2023_06.csv (utf-8 / ';')
# 2025-03-02 16:22:06,215 [INFO] Converting 'hydrogen/VRA_2018_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_06.csv (utf-8 / ';')
# 2025-03-02 16:22:06,546 [INFO] Converting 'hydrogen/VRA_2012_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_02.csv (utf-8 / ';')
# 2025-03-02 16:22:07,084 [INFO] Converting 'hydrogen/VRA_20056.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20056.csv (utf-8 / ';')
# 2025-03-02 16:22:07,184 [INFO] Converting 'hydrogen/VRA_2014_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_04.csv (utf-8 / ';')
# 2025-03-02 16:22:07,719 [INFO] Converting 'hydrogen/VRA_200611.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200611.csv (utf-8 / ';')
# 2025-03-02 16:22:07,916 [INFO] Converting 'hydrogen/VRA_20036.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20036.csv (utf-8 / ';')
# 2025-03-02 16:22:08,005 [INFO] Converting 'hydrogen/VRA_2016_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_04.csv (utf-8 / ';')
# 2025-03-02 16:22:08,490 [INFO] Converting 'hydrogen/VRA_20026.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20026.csv (utf-8 / ';')
# 2025-03-02 16:22:08,696 [INFO] Converting 'hydrogen/VRA_200710.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200710.csv (utf-8 / ';')
# 2025-03-02 16:22:08,832 [INFO] Converting 'hydrogen/VRA_2010_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_09.csv (utf-8 / ';')
# 2025-03-02 16:22:09,239 [INFO] Converting 'hydrogen/VRA_2018_09.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2018_09.csv (utf-8 / ';')
# 2025-03-02 16:22:09,666 [INFO] Converting 'hydrogen/VRA_20059.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20059.csv (utf-8 / ';')
# 2025-03-02 16:22:09,859 [INFO] Converting 'hydrogen/VRA_20051.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20051.csv (utf-8 / ';')
# 2025-03-02 16:22:09,959 [INFO] Converting 'hydrogen/VRA_2016_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2016_12.csv (utf-8 / ';')
# 2025-03-02 16:22:10,325 [INFO] Converting 'hydrogen/VRA_2015_04.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2015_04.csv (utf-8 / ';')
# 2025-03-02 16:22:10,767 [INFO] Converting 'hydrogen/VRA_2012_11.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_11.csv (utf-8 / ';')
# 2025-03-02 16:22:11,206 [INFO] Converting 'hydrogen/VRA_2019_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2019_12.csv (utf-8 / ';')
# 2025-03-02 16:22:11,566 [INFO] Converting 'hydrogen/VRA_2014_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2014_10.csv (utf-8 / ';')
# 2025-03-02 16:22:12,110 [INFO] Converting 'hydrogen/VRA_200211.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200211.csv (utf-8 / ';')
# 2025-03-02 16:22:12,219 [INFO] Converting 'hydrogen/VRA_2012_10.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_10.csv (utf-8 / ';')
# 2025-03-02 16:22:12,664 [INFO] Converting 'hydrogen/VRA_2022_02.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_02.csv (utf-8 / ';')
# 2025-03-02 16:22:12,986 [INFO] Converting 'hydrogen/VRA_200811.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200811.csv (utf-8 / ';')
# 2025-03-02 16:22:13,187 [INFO] Converting 'hydrogen/VRA_200711.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200711.csv (utf-8 / ';')
# 2025-03-02 16:22:13,307 [INFO] Converting 'hydrogen/VRA_2012_12.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2012_12.csv (utf-8 / ';')
# 2025-03-02 16:22:13,841 [INFO] Converting 'hydrogen/VRA_200612.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_200612.csv (utf-8 / ';')
# 2025-03-02 16:22:13,956 [INFO] Converting 'hydrogen/VRA_2022_06.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2022_06.csv (utf-8 / ';')
# 2025-03-02 16:22:14,227 [INFO] Converting 'hydrogen/VRA_2010_01.csv' | Detected Encoding='utf-8' Delimiter=';' -> helium/VRA_2010_01.csv (utf-8 / ';')
# 2025-03-02 16:22:14,757 [INFO] Converting 'hydrogen/VRA_20012.csv' | Detected Encoding='ISO-8859-1' Delimiter=',' -> helium/VRA_20012.csv (utf-8 / ';')
# 2025-03-02 16:22:14,843 [INFO] Conversion complete. 301 file(s) processed.

# %% [markdown]
# # Overview
#
# This script tidies up your CSV filenames by enforcing a strict naming convention: "VRA_YYYY_MM.csv", ensuring consistency across your data files.
#
# ## What it does
#
# - **Filename evaluation:**
#   Scans through all CSV files in the designated folder and checks whether each filename matches one of the recognized patterns. If a file is already formatted correctly, it leaves it alone; otherwise, it prepares a new name.
#
# - **Pattern matching magic:**
#   Uses regex to detect three scenarios:
#   1. Files already in the ideal "VRA_YYYY_MM.csv" format.
#   2. Files in a "VRA_YYYYMM.csv" format (six digits) which are split into year and month.
#   3. Files in a "VRA_YYYYM.csv" format (five digits) where the month is zero-padded.
#
#   If a file doesn't match any known pattern, it gets skipped with a warning.
#
# - **In-place renaming:**
#   Renames files directly, even overwriting existing files if necessary.
#
# ## Why it does it
#
# With a uniform naming scheme, your data is easier to manage and reference, meaning less time cleaning up and more time focusing on the important work.

# %%
def standardize_csv_filenames(source_folder="helium"):
    """
    Reads all .csv files from `source_folder` and renames them in place to match 
    the pattern 'VRA_YYYY_MM.csv'. The rules are:
    
      1) If already 'VRA_YYYY_MM.csv', leave it unchanged.
      2) If 'VRA_YYYYMM.csv' (6 digits after underscore), split into year and month.
      3) If 'VRA_YYYYM.csv' (5 digits after underscore), split and zero-pad the month.
      4) Otherwise, skip (and log a warning).
      
    If a file with the new name already exists, it will be overwritten.
    """
    # Regex patterns for matching file naming conventions
    already_ok_pattern = re.compile(r'^VRA_(\d{4})_(\d{2})\.csv$', re.IGNORECASE)
    six_digit_pattern   = re.compile(r'^VRA_(\d{6})\.csv$', re.IGNORECASE)  # e.g., VRA_200010.csv
    five_digit_pattern  = re.compile(r'^VRA_(\d{5})\.csv$', re.IGNORECASE)  # e.g., VRA_20001.csv

    files_processed = 0
    for filename in os.listdir(source_folder):
        if not filename.lower().endswith(".csv"):
            continue  # Skip non-CSV files

        source_path = os.path.join(source_folder, filename)
        new_name = None

        # Check if file is already in the correct format.
        if already_ok_pattern.match(filename):
            new_name = filename  # Leave it unchanged.
        else:
            # Check for a six-digit pattern: VRA_YYYYMM.csv
            m_six = six_digit_pattern.match(filename)
            # Check for a five-digit pattern: VRA_YYYYM.csv
            m_five = five_digit_pattern.match(filename)

            if m_six:
                digits = m_six.group(1)  # e.g. '200010'
                year = digits[:4]         # '2000'
                month = digits[4:]        # '10'
                new_name = f"VRA_{year}_{month}.csv"
            elif m_five:
                digits = m_five.group(1)  # e.g. '20001'
                year = digits[:4]         # '2000'
                month = digits[4:]        # '1'
                month = month.zfill(2)    # zero-pad to '01'
                new_name = f"VRA_{year}_{month}.csv"
            else:
                logging.warning(f"Skipping file '{filename}': does not match known patterns.")
                continue

        # Rename file in place if needed.
        if new_name and new_name != filename:
            target_path = os.path.join(source_folder, new_name)
            # Overwrite if target file already exists.
            if os.path.exists(target_path):
                os.remove(target_path)
            os.rename(source_path, target_path)
            logging.info(f"Renamed '{filename}' -> '{new_name}'")
            files_processed += 1
        else:
            logging.info(f"No renaming needed for '{filename}'")
            
    logging.info(f"All done. Processed {files_processed} file(s).")

# %%
logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
standardize_csv_filenames(source_folder="helium")
# Out:
# 2025-03-02 16:22:28,051 [INFO] Renamed 'VRA_20072.csv' -> 'VRA_2007_02.csv'
# 2025-03-02 16:22:28,051 [INFO] No renaming needed for 'VRA_2023_02.csv'
# 2025-03-02 16:22:28,052 [INFO] Renamed 'VRA_200311.csv' -> 'VRA_2003_11.csv'
# 2025-03-02 16:22:28,052 [INFO] No renaming needed for 'VRA_2010_06.csv'
# 2025-03-02 16:22:28,052 [INFO] No renaming needed for 'VRA_2024_04.csv'
# 2025-03-02 16:22:28,053 [INFO] No renaming needed for 'VRA_2014_09.csv'
# 2025-03-02 16:22:28,053 [INFO] No renaming needed for 'VRA_2016_10.csv'
# 2025-03-02 16:22:28,053 [INFO] Renamed 'VRA_20004.csv' -> 'VRA_2000_04.csv'
# 2025-03-02 16:22:28,054 [INFO] Renamed 'VRA_20046.csv' -> 'VRA_2004_06.csv'
# 2025-03-02 16:22:28,054 [INFO] No renaming needed for 'VRA_2022_04.csv'
# 2025-03-02 16:22:28,055 [INFO] Renamed 'VRA_20075.csv' -> 'VRA_2007_05.csv'
# 2025-03-02 16:22:28,055 [INFO] No renaming needed for 'VRA_2020_02.csv'
# 2025-03-02 16:22:28,055 [INFO] No renaming needed for 'VRA_2010_02.csv'
# 2025-03-02 16:22:28,055 [INFO] Renamed 'VRA_20048.csv' -> 'VRA_2004_08.csv'
# 2025-03-02 16:22:28,055 [INFO] Renamed 'VRA_20092.csv' -> 'VRA_2009_02.csv'
# 2025-03-02 16:22:28,056 [INFO] No renaming needed for 'VRA_2014_05.csv'
# 2025-03-02 16:22:28,056 [INFO] No renaming needed for 'VRA_2017_10.csv'
# 2025-03-02 16:22:28,056 [INFO] No renaming needed for 'VRA_2020_11.csv'
# 2025-03-02 16:22:28,056 [INFO] No renaming needed for 'VRA_2018_02.csv'
# 2025-03-02 16:22:28,056 [INFO] No renaming needed for 'VRA_2014_03.csv'
# 2025-03-02 16:22:28,057 [INFO] No renaming needed for 'VRA_2017_09.csv'
# 2025-03-02 16:22:28,057 [INFO] Renamed 'VRA_200010.csv' -> 'VRA_2000_10.csv'
# 2025-03-02 16:22:28,057 [INFO] No renaming needed for 'VRA_2021_10.csv'
# 2025-03-02 16:22:28,057 [INFO] Renamed 'VRA_20096.csv' -> 'VRA_2009_06.csv'
# 2025-03-02 16:22:28,058 [INFO] No renaming needed for 'VRA_2017_12.csv'
# 2025-03-02 16:22:28,058 [INFO] No renaming needed for 'VRA_2018_12.csv'
# 2025-03-02 16:22:28,058 [INFO] No renaming needed for 'VRA_2011_03.csv'
# 2025-03-02 16:22:28,058 [INFO] No renaming needed for 'VRA_2013_04.csv'
# 2025-03-02 16:22:28,089 [INFO] No renaming needed for 'VRA_2019_02.csv'
# 2025-03-02 16:22:28,089 [INFO] Renamed 'VRA_20011.csv' -> 'VRA_2001_01.csv'
# 2025-03-02 16:22:28,090 [INFO] Renamed 'VRA_20064.csv' -> 'VRA_2006_04.csv'
# 2025-03-02 16:22:28,090 [INFO] No renaming needed for 'VRA_2021_03.csv'
# 2025-03-02 16:22:28,091 [INFO] No renaming needed for 'VRA_2022_11.csv'
# 2025-03-02 16:22:28,091 [INFO] Renamed 'VRA_20006.csv' -> 'VRA_2000_06.csv'
# 2025-03-02 16:22:28,091 [INFO] No renaming needed for 'VRA_2011_05.csv'
# 2025-03-02 16:22:28,092 [INFO] No renaming needed for 'VRA_2021_07.csv'
# 2025-03-02 16:22:28,092 [INFO] Renamed 'VRA_20088.csv' -> 'VRA_2008_08.csv'
# 2025-03-02 16:22:28,092 [INFO] Renamed 'VRA_200011.csv' -> 'VRA_2000_11.csv'
# 2025-03-02 16:22:28,093 [INFO] Renamed 'VRA_200911.csv' -> 'VRA_2009_11.csv'
# 2025-03-02 16:22:28,093 [INFO] Renamed 'VRA_200912.csv' -> 'VRA_2009_12.csv'
# 2025-03-02 16:22:28,093 [INFO] No renaming needed for 'VRA_2020_06.csv'
# 2025-03-02 16:22:28,094 [INFO] No renaming needed for 'VRA_2012_09.csv'
# 2025-03-02 16:22:28,094 [INFO] Renamed 'VRA_20042.csv' -> 'VRA_2004_02.csv'
# 2025-03-02 16:22:28,094 [INFO] No renaming needed for 'VRA_2013_03.csv'
# 2025-03-02 16:22:28,094 [INFO] No renaming needed for 'VRA_2024_02.csv'
# 2025-03-02 16:22:28,094 [INFO] No renaming needed for 'VRA_2019_11.csv'
# 2025-03-02 16:22:28,095 [INFO] No renaming needed for 'VRA_2014_08.csv'
# 2025-03-02 16:22:28,095 [INFO] Renamed 'VRA_20047.csv' -> 'VRA_2004_07.csv'
# 2025-03-02 16:22:28,095 [INFO] Renamed 'VRA_20069.csv' -> 'VRA_2006_09.csv'
# 2025-03-02 16:22:28,095 [INFO] Renamed 'VRA_20052.csv' -> 'VRA_2005_02.csv'
# 2025-03-02 16:22:28,096 [INFO] No renaming needed for 'VRA_2020_07.csv'
# 2025-03-02 16:22:28,096 [INFO] No renaming needed for 'VRA_2022_01.csv'
# 2025-03-02 16:22:28,096 [INFO] No renaming needed for 'VRA_2011_12.csv'
# 2025-03-02 16:22:28,096 [INFO] Renamed 'VRA_20038.csv' -> 'VRA_2003_08.csv'
# 2025-03-02 16:22:28,096 [INFO] No renaming needed for 'VRA_2014_06.csv'
# 2025-03-02 16:22:28,096 [INFO] No renaming needed for 'VRA_2014_11.csv'
# 2025-03-02 16:22:28,096 [INFO] No renaming needed for 'VRA_2017_05.csv'
# 2025-03-02 16:22:28,097 [INFO] Renamed 'VRA_20095.csv' -> 'VRA_2009_05.csv'
# 2025-03-02 16:22:28,097 [INFO] Renamed 'VRA_200112.csv' -> 'VRA_2001_12.csv'
# 2025-03-02 16:22:28,097 [INFO] No renaming needed for 'VRA_2012_04.csv'
# 2025-03-02 16:22:28,097 [INFO] No renaming needed for 'VRA_2016_11.csv'
# 2025-03-02 16:22:28,097 [INFO] Renamed 'VRA_20009.csv' -> 'VRA_2000_09.csv'
# 2025-03-02 16:22:28,097 [INFO] No renaming needed for 'VRA_2023_09.csv'
# 2025-03-02 16:22:28,097 [INFO] No renaming needed for 'VRA_2022_03.csv'
# 2025-03-02 16:22:28,098 [INFO] No renaming needed for 'VRA_2010_07.csv'
# 2025-03-02 16:22:28,098 [INFO] No renaming needed for 'VRA_2022_09.csv'
# 2025-03-02 16:22:28,098 [INFO] Renamed 'VRA_200512.csv' -> 'VRA_2005_12.csv'
# 2025-03-02 16:22:28,098 [INFO] No renaming needed for 'VRA_2017_02.csv'
# 2025-03-02 16:22:28,098 [INFO] No renaming needed for 'VRA_2022_10.csv'
# 2025-03-02 16:22:28,098 [INFO] No renaming needed for 'VRA_2010_05.csv'
# 2025-03-02 16:22:28,099 [INFO] Renamed 'VRA_20066.csv' -> 'VRA_2006_06.csv'
# 2025-03-02 16:22:28,099 [INFO] Renamed 'VRA_20013.csv' -> 'VRA_2001_03.csv'
# 2025-03-02 16:22:28,099 [INFO] Renamed 'VRA_200411.csv' -> 'VRA_2004_11.csv'
# 2025-03-02 16:22:28,099 [INFO] No renaming needed for 'VRA_2015_09.csv'
# 2025-03-02 16:22:28,099 [INFO] No renaming needed for 'VRA_2010_08.csv'
# 2025-03-02 16:22:28,099 [INFO] Renamed 'VRA_200410.csv' -> 'VRA_2004_10.csv'
# 2025-03-02 16:22:28,100 [INFO] Renamed 'VRA_20097.csv' -> 'VRA_2009_07.csv'
# 2025-03-02 16:22:28,100 [INFO] No renaming needed for 'VRA_2024_08.csv'
# 2025-03-02 16:22:28,100 [INFO] Renamed 'VRA_20087.csv' -> 'VRA_2008_07.csv'
# 2025-03-02 16:22:28,100 [INFO] No renaming needed for 'VRA_2022_05.csv'
# 2025-03-02 16:22:28,100 [INFO] No renaming needed for 'VRA_2011_06.csv'
# 2025-03-02 16:22:28,100 [INFO] No renaming needed for 'VRA_2016_07.csv'
# 2025-03-02 16:22:28,100 [INFO] No renaming needed for 'VRA_2015_06.csv'
# 2025-03-02 16:22:28,101 [INFO] Renamed 'VRA_200312.csv' -> 'VRA_2003_12.csv'
# 2025-03-02 16:22:28,101 [INFO] No renaming needed for 'VRA_2023_08.csv'
# 2025-03-02 16:22:28,101 [INFO] No renaming needed for 'VRA_2022_12.csv'
# 2025-03-02 16:22:28,101 [INFO] Renamed 'VRA_20086.csv' -> 'VRA_2008_06.csv'
# 2025-03-02 16:22:28,101 [INFO] Renamed 'VRA_20061.csv' -> 'VRA_2006_01.csv'
# 2025-03-02 16:22:28,101 [INFO] Renamed 'VRA_20079.csv' -> 'VRA_2007_09.csv'
# 2025-03-02 16:22:28,101 [INFO] No renaming needed for 'VRA_2011_01.csv'
# 2025-03-02 16:22:28,102 [INFO] No renaming needed for 'VRA_2019_04.csv'
# 2025-03-02 16:22:28,102 [INFO] Renamed 'VRA_20091.csv' -> 'VRA_2009_01.csv'
# 2025-03-02 16:22:28,102 [INFO] No renaming needed for 'VRA_2010_10.csv'
# 2025-03-02 16:22:28,102 [INFO] No renaming needed for 'VRA_2021_06.csv'
# 2025-03-02 16:22:28,102 [INFO] Renamed 'VRA_20045.csv' -> 'VRA_2004_05.csv'
# 2025-03-02 16:22:28,127 [INFO] Renamed 'VRA_20083.csv' -> 'VRA_2008_03.csv'
# 2025-03-02 16:22:28,127 [INFO] Renamed 'VRA_200712.csv' -> 'VRA_2007_12.csv'
# 2025-03-02 16:22:28,127 [INFO] No renaming needed for 'VRA_2018_10.csv'
# 2025-03-02 16:22:28,127 [INFO] No renaming needed for 'VRA_2023_01.csv'
# 2025-03-02 16:22:28,127 [INFO] No renaming needed for 'VRA_2011_09.csv'
# 2025-03-02 16:22:28,128 [INFO] No renaming needed for 'VRA_2025_01.csv'
# 2025-03-02 16:22:28,128 [INFO] Renamed 'VRA_200212.csv' -> 'VRA_2002_12.csv'
# 2025-03-02 16:22:28,128 [INFO] No renaming needed for 'VRA_2020_04.csv'
# 2025-03-02 16:22:28,129 [INFO] Renamed 'VRA_20028.csv' -> 'VRA_2002_08.csv'
# 2025-03-02 16:22:28,129 [INFO] Renamed 'VRA_20022.csv' -> 'VRA_2002_02.csv'
# 2025-03-02 16:22:28,129 [INFO] Renamed 'VRA_20008.csv' -> 'VRA_2000_08.csv'
# 2025-03-02 16:22:28,130 [INFO] No renaming needed for 'VRA_2013_01.csv'
# 2025-03-02 16:22:28,130 [INFO] Renamed 'VRA_20093.csv' -> 'VRA_2009_03.csv'
# 2025-03-02 16:22:28,130 [INFO] Renamed 'VRA_20029.csv' -> 'VRA_2002_09.csv'
# 2025-03-02 16:22:28,131 [INFO] Renamed 'VRA_20098.csv' -> 'VRA_2009_08.csv'
# 2025-03-02 16:22:28,131 [INFO] Renamed 'VRA_20055.csv' -> 'VRA_2005_05.csv'
# 2025-03-02 16:22:28,131 [INFO] Renamed 'VRA_20005.csv' -> 'VRA_2000_05.csv'
# 2025-03-02 16:22:28,132 [INFO] No renaming needed for 'VRA_2024_07.csv'
# 2025-03-02 16:22:28,132 [INFO] Renamed 'VRA_200511.csv' -> 'VRA_2005_11.csv'
# 2025-03-02 16:22:28,132 [INFO] No renaming needed for 'VRA_2015_01.csv'
# 2025-03-02 16:22:28,132 [INFO] No renaming needed for 'VRA_2013_08.csv'
# 2025-03-02 16:22:28,132 [INFO] Renamed 'VRA_20021.csv' -> 'VRA_2002_01.csv'
# 2025-03-02 16:22:28,133 [INFO] Renamed 'VRA_200310.csv' -> 'VRA_2003_10.csv'
# 2025-03-02 16:22:28,133 [INFO] Renamed 'VRA_20043.csv' -> 'VRA_2004_03.csv'
# 2025-03-02 16:22:28,133 [INFO] Renamed 'VRA_20053.csv' -> 'VRA_2005_03.csv'
# 2025-03-02 16:22:28,133 [INFO] No renaming needed for 'VRA_2024_06.csv'
# 2025-03-02 16:22:28,133 [INFO] No renaming needed for 'VRA_2017_06.csv'
# 2025-03-02 16:22:28,134 [INFO] Renamed 'VRA_20078.csv' -> 'VRA_2007_08.csv'
# 2025-03-02 16:22:28,134 [INFO] Renamed 'VRA_20023.csv' -> 'VRA_2002_03.csv'
# 2025-03-02 16:22:28,134 [INFO] No renaming needed for 'VRA_2016_02.csv'
# 2025-03-02 16:22:28,140 [INFO] All done. Processed 120 file(s).

# %%
def check_all_vra_files(folder="helium"):
    """
    Verifies that all files named 'VRA_YYYY_MM.csv' exist for
    every year from 2000 to 2025 and every month (01..12).

    Logs any missing files or confirms all are present.
    """
    missing = []
    for year in range(2000, 2026):
        for month in range(1, 13):
            month_str = str(month).zfill(2)  # zero-pad, e.g. 1 -> '01'
            expected_name = f"VRA_{year}_{month_str}.csv"
            expected_path = os.path.join(folder, expected_name)
            if not os.path.isfile(expected_path):
                missing.append(expected_name)

    if missing:
        logging.info(f"Missing {len(missing)} file(s) in '{folder}': {missing}")
    else:
        logging.info(f"All files from 2000-01 to 2025-12 are present in '{folder}'.")

# %%
logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
check_all_vra_files(folder="helium")
# Out:
# 2025-03-02 16:22:38,747 [INFO] Missing 11 file(s) in 'helium': ['VRA_2025_02.csv', 'VRA_2025_03.csv', 'VRA_2025_04.csv', 'VRA_2025_05.csv', 'VRA_2025_06.csv', 'VRA_2025_07.csv', 'VRA_2025_08.csv', 'VRA_2025_09.csv', 'VRA_2025_10.csv', 'VRA_2025_11.csv', 'VRA_2025_12.csv']

# %% [markdown]
# # Overview
#
# This script scans a folder of CSV files to check if their columns follow the expected patterns for two different eras—files from 2000–2009 versus 2010–2025. It logs the standard column names for each period and flags any files that dare to deviate from the norm.
#
# ## What it does
#
# - **Log folder setup:**
#   It makes sure the log folder exists, creating it if necessary.
#
# - **Column extraction:**
#   Iterates over every CSV file in the source folder, extracting column names using a CSV reader (powered by Polars). It uses the filename (assuming the format "VRA_YYYY...") to determine the file’s era.
#
# - **Pattern grouping:**
#   Files are split into two groups: 2000–2009 and 2010–2025. Each group should have a consistent set of column names. If not, the script notes the discrepancies.
#
# - **Logging discrepancies:**
#   It writes all this info into a log file, detailing the expected column names for each group and listing any files that broke the rules.
#
# ## Why it does it
#
# Because manually checking CSV column patterns is as fun as watching paying bills. This utility automates the process, ensuring your data conforms to expected standards and letting you know exactly which files are off the reservation.

# %%
def log_column_patterns(source_folder="helium", log_folder="logging"):
    """
    Iterates over all CSV files in the source_folder and extracts their column names.
    Files from 2000–2009 are assumed to follow one column pattern and files from 2010–2025 a different one.
    It writes a log file (column_patterns.log) in log_folder with the following:
      - The expected column names for files in each time period.
      - Any discrepancies if some files within a group have different columns.
    """
    # Ensure the log folder exists.
    if not os.path.exists(log_folder):
        os.makedirs(log_folder, exist_ok=True)
        logging.info(f"Created log folder: {log_folder}")
    
    # Prepare containers to hold the expected columns for each pattern
    pattern1_columns = None  # for 2000-2009
    pattern2_columns = None  # for 2010-2025
    discrepancies = []       # list of (filename, group, columns)

    # Process each CSV file in the source folder.
    for filename in os.listdir(source_folder):
        if not filename.lower().endswith(".csv"):
            continue  # Skip non-CSV files
        
        source_path = os.path.join(source_folder, filename)
        
        # Try to extract the year from the filename. Assumes format "VRA_YYYY..."
        match = re.search(r'VRA_(\d{4})', filename, re.IGNORECASE)
        if not match:
            logging.warning(f"Could not extract year from filename: {filename}")
            continue
        
        year = int(match.group(1))
        
        try:
            df = pl.read_csv(source_path)
        except Exception as e:
            logging.error(f"Error reading {filename}: {e}")
            continue
        
        cols = df.columns  # list of column names
        
        # Group files by year pattern.
        if year < 2010:
            # 2000-2009
            if pattern1_columns is None:
                pattern1_columns = cols
            else:
                if pattern1_columns != cols:
                    discrepancies.append((filename, "2000-2009", cols))
        else:
            # 2010-2025
            if pattern2_columns is None:
                pattern2_columns = cols
            else:
                if pattern2_columns != cols:
                    discrepancies.append((filename, "2010-2025", cols))
    
    # Write out the log file.
    log_filename = os.path.join(log_folder, "column_patterns.log")
    with open(log_filename, "w") as log_file:
        log_file.write("Column Patterns Log\n")
        log_file.write("===================\n\n")
        
        if pattern1_columns is not None:
            log_file.write("Pattern for years 2000-2009:\n")
            log_file.write(", ".join(pattern1_columns) + "\n\n")
        else:
            log_file.write("No files found for years 2000-2009.\n\n")
        
        if pattern2_columns is not None:
            log_file.write("Pattern for years 2010-2025:\n")
            log_file.write(", ".join(pattern2_columns) + "\n\n")
        else:
            log_file.write("No files found for years 2010-2025.\n\n")
        
        if discrepancies:
            log_file.write("Discrepancies found:\n")
            for fname, group, cols in discrepancies:
                log_file.write(f"{fname} in group {group} has columns: {cols}\n")
        else:
            log_file.write("No discrepancies found among files in each group.\n")
    
    logging.info(f"Column patterns logged to {log_filename}")

# %%
logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
log_column_patterns(source_folder="helium", log_folder="logging")
# Out:
# 2025-03-02 16:23:14,129 [INFO] Created log folder: logging
# 2025-03-02 16:23:14,172 [ERROR] Error reading VRA_2023_02.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,182 [ERROR] Error reading VRA_2010_06.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,186 [ERROR] Error reading VRA_2024_04.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,190 [ERROR] Error reading VRA_2014_09.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,198 [ERROR] Error reading VRA_2016_10.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,203 [ERROR] Error reading VRA_2022_04.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,208 [ERROR] Error reading VRA_2020_02.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,215 [ERROR] Error reading VRA_2010_02.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,220 [ERROR] Error reading VRA_2014_05.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,228 [ERROR] Error reading VRA_2017_10.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,231 [ERROR] Error reading VRA_2020_11.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,236 [ERROR] Error reading VRA_2018_02.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,241 [ERROR] Error reading VRA_2014_03.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,245 [ERROR] Error reading VRA_2017_09.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,250 [ERROR] Error reading VRA_2021_10.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,255 [ERROR] Error reading VRA_2017_12.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,259 [ERROR] Error reading VRA_2018_12.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,264 [ERROR] Error reading VRA_2011_03.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,268 [ERROR] Error reading VRA_2013_04.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,273 [ERROR] Error reading VRA_2013_07.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,278 [ERROR] Error reading VRA_2017_11.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,282 [ERROR] Error reading VRA_2019_05.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,287 [ERROR] Error reading VRA_2011_04.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,292 [ERROR] Error reading VRA_2012_03.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,297 [ERROR] Error reading VRA_2013_10.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,301 [ERROR] Error reading VRA_2015_11.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,306 [ERROR] Error reading VRA_2011_08.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,311 [ERROR] Error reading VRA_2019_01.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,315 [ERROR] Error reading VRA_2023_10.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,320 [ERROR] Error reading VRA_2015_07.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,327 [ERROR] Error reading VRA_2017_04.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,332 [ERROR] Error reading VRA_2022_07.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,338 [ERROR] Error reading VRA_2017_07.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,343 [ERROR] Error reading VRA_2020_12.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,350 [ERROR] Error reading VRA_2020_03.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,360 [ERROR] Error reading VRA_2024_05.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,364 [ERROR] Error reading VRA_2017_03.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14,371 [ERROR] Error reading VRA_2010_03.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:14
csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:15,231 [ERROR] Error reading VRA_2010_01.csv: found more fields than defined in 'Schema'
#
# Consider setting 'truncate_ragged_lines=True'.
# 2025-03-02 16:23:15,236 [INFO] Column patterns logged to logging/column_patterns.log

# %%
old_mapping = {
    "ICAO Empresa Aérea":       "empresa_aerea",      
    "Número Voo":               "numero_voo",  
    "Código Autorização (DI)":  "codigo_DI",
    "Código Tipo Linha":        "codigo_tipo_linha", 
    "ICAO Aeródromo Origem":    "aeroporto_origem",   
    "ICAO Aeródromoo Destino":  "aeroporto_destino",  
    "Partida Prevista":         "partida_prevista", 
    "Partida Real":             "partida_real",  
    "Chegada Prevista":         "chegada_prevista", 
    "Chegada Real":             "chegada_real", 
    "Situação Voo":             "situacao_voo",
    "Código Justificativa":     "justificativa"
}

new_columns = {
    "long_empresa_aerea",
    "modelo_equipamento",
    "numero_assentos",
    "descricao_aeroporto_origem",
    "descricao_aeroporto_destino",
    "referencia",
    "situacao_partida",
    "situacao_chegada"    
}

new_mapping = {
    "Sigla ICAO Empresa Aérea":     "empresa_aerea",
    "Empresa Aérea":                "long_empresa_aerea",
    "Número Voo":                   "numero_voo",
    "Código DI":                    "codigo_DI",
    "Código Tipo Linha":            "codigo_tipo_linha",
    "Modelo Equipamento":           "modelo_equipamento",
    "Número de Assentos":           "numero_assentos",
    "Sigla ICAO Aerodromo Origem":  "aeroporto_origem",
    "Descrição Aeroporto Origem":   "descricao_aeroporto_origem",
    "Partida Prevista":             "partida_prevista",
    "Partida Real":                 "partida_real",
    "Sigla ICAO Aeroporto Destino": "aeroporto_destino",
    "Descrição Aeroporto Destino":  "descricao_aeroporto_destino",
    "Chegada Prevista":             "chegada_prevista",
    "Chegada Real":                 "chegada_real",
    "Situação Voo":                 "situacao_voo",
    "Justificativa":                "justificativa",
    "Referência":                   "referencia",
    "Situação Partida":             "situacao_partida",
    "Situação Chegada":             "situacao_chegada"
}

# Desired column order
desired_order = [
    "empresa_aerea",
    "long_empresa_aerea",
    "numero_voo",
    "codigo_DI",
    "codigo_tipo_linha",
    "modelo_equipamento",
    "numero_assentos",
    "aeroporto_origem",
    "descricao_aeroporto_origem",
    "partida_prevista",
    "partida_real",
    "aeroporto_destino",
    "descricao_aeroporto_destino",
    "chegada_prevista",
    "chegada_real",
    "situacao_voo",
    "justificativa",
    "referencia",
    "situacao_partida",
    "situacao_chegada"
]

# %% [markdown]
# # Overview
#
# This script processes CSV files following the "VRA_YYYY_MM.csv" naming convention within a designated folder. It sets up detailed logging to capture every success and failure, then iterates over each file for years 2000–2009. Using Polars, it reads each CSV as strings, renames columns based on a predefined mapping, adds any missing new columns, and overwrites the file—all while recording its every move.
#
# ## What it does
#
# - **Logging configuration:**
#   Configures logging to output to "csv_processing.log" with timestamps and log levels, ensuring that every action and error is documented.
#
# - **File iteration:**
#   Loops through each month for each year from 2000 to 2009, constructing the expected filename and checking if it exists in the input folder ("helium").
#
# - **CSV processing:**
#   For every found file, the script:
#   - Reads the CSV with Polars, forcing all columns to be treated as strings.
#   - Renames the columns based on an `old_mapping` dictionary.
#   - Adds any missing columns from `new_columns`, populating them with `None`.
#   - Overwrites the original CSV with the updated data using semicolon delimiters.
#
# - **Error handling:**
#   Logs every successful overwrite, and if something goes wrong, logs an error with the file's name and the exception encountered.
#
# ## Why it does it
#
# This script eliminates the tedious manual labor of updating CSV files by automating the process. It enforces consistency and proper formatting so you can watch PSG dominate Liverpool in the entire game and still, somehow, some inexplicable how, lose the game.

# %%
# Configure logging
log_file = "csv_processing.log"
logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# Folder containing the files
input_folder = "helium"

def process_csv_files():
    for year in range(2000, 2010):  # From 2000 to 2009
        for month in range(1, 13):  # January to December
            file_name = f"VRA_{year}_{month:02d}.csv"
            file_path = os.path.join(input_folder, file_name)
            
            if os.path.exists(file_path):
                try:
                    # Read CSV with all columns as string using Polars
                    df = pl.read_csv(file_path, separator=";", encoding="utf-8", dtypes={col: pl.Utf8 for col in old_mapping.keys()})

                    # Rename columns based on mapping
                    df = df.rename(old_mapping)

                    # Add missing new columns filled with None
                    for col in new_columns:
                        if col not in df.columns:
                            df = df.with_columns(pl.lit(None).alias(col))

                    # Overwrite the existing CSV
                    df.write_csv(file_path, separator=";", include_header=True)

                    logging.info(f"Overwritten: {file_name}")

                except Exception as e:
                    logging.error(f"Error processing {file_name}: {e}")

# %%
logging.info("CSV processing (overwrite mode) started.")
process_csv_files()
logging.info("CSV processing (overwrite mode) completed.")
# Out:
# 2025-03-02 17:00:07,179 [INFO] CSV processing (overwrite mode) started.
# /tmp/ipykernel_3968/3828917261.py:22: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   df = pl.read_csv(file_path, separator=";", encoding="utf-8", dtypes={col: pl.Utf8 for col in old_mapping.keys()})
# 2025-03-02 17:00:07,222 [INFO] Overwritten: VRA_2000_01.csv
# 2025-03-02 17:00:07,259 [INFO] Overwritten: VRA_2000_02.csv
# 2025-03-02 17:00:07,295 [INFO] Overwritten: VRA_2000_03.csv
# 2025-03-02 17:00:07,334 [INFO] Overwritten: VRA_2000_04.csv
# 2025-03-02 17:00:07,368 [INFO] Overwritten: VRA_2000_05.csv
# 2025-03-02 17:00:07,399 [INFO] Overwritten: VRA_2000_06.csv
# 2025-03-02 17:00:07,433 [INFO] Overwritten: VRA_2000_07.csv
# 2025-03-02 17:00:07,470 [INFO] Overwritten: VRA_2000_08.csv
# 2025-03-02 17:00:07,504 [INFO] Overwritten: VRA_2000_09.csv
# 2025-03-02 17:00:07,538 [INFO] Overwritten: VRA_2000_10.csv
# 2025-03-02 17:00:07,574 [INFO] Overwritten: VRA_2000_11.csv
# 2025-03-02 17:00:07,608 [INFO] Overwritten: VRA_2000_12.csv
# 2025-03-02 17:00:07,642 [INFO] Overwritten: VRA_2001_01.csv
# 2025-03-02 17:00:07,677 [INFO] Overwritten: VRA_2001_02.csv
# 2025-03-02 17:00:07,711 [INFO] Overwritten: VRA_2001_03.csv
# 2025-03-02 17:00:07,744 [INFO] Overwritten: VRA_2001_04.csv
# 2025-03-02 17:00:07,778 [INFO] Overwritten: VRA_2001_05.csv
# 2025-03-02 17:00:07,811 [INFO] Overwritten: VRA_2001_06.csv
# 2025-03-02 17:00:07,845 [INFO] Overwritten: VRA_2001_07.csv
# 2025-03-02 17:00:07,879 [INFO] Overwritten: VRA_2001_08.csv
# 2025-03-02 17:00:07,913 [INFO] Overwritten: VRA_2001_09.csv
# 2025-03-02 17:00:07,947 [INFO] Overwritten: VRA_2001_10.csv
# 2025-03-02 17:00:07,980 [INFO] Overwritten: VRA_2001_11.csv
# 2025-03-02 17:00:08,015 [INFO] Overwritten: VRA_2001_12.csv
# 2025-03-02 17:00:10,426 [INFO] Overwritten: VRA_2008_06.csv
# 2025-03-02 17:00:10,459 [INFO] Overwritten: VRA_2008_07.csv
# 2025-03-02 17:00:10,492 [INFO] Overwritten: VRA_2008_08.csv
# 2025-03-02 17:00:10,525 [INFO] Overwritten: VRA_2008_09.csv
# 2025-03-02 17:00:10,556 [INFO] Overwritten: VRA_2008_10.csv
# 2025-03-02 17:00:10,589 [INFO] Overwritten: VRA_2008_11.csv
# 2025-03-02 17:00:10,622 [INFO] Overwritten: VRA_2008_12.csv
# 2025-03-02 17:00:10,656 [INFO] Overwritten: VRA_2009_01.csv
# 2025-03-02 17:00:10,690 [INFO] Overwritten: VRA_2009_02.csv
# 2025-03-02 17:00:10,725 [INFO] Overwritten: VRA_2009_03.csv
# 2025-03-02 17:00:10,759 [INFO] Overwritten: VRA_2009_04.csv
# 2025-03-02 17:00:10,793 [INFO] Overwritten: VRA_2009_05.csv
# 2025-03-02 17:00:10,828 [INFO] Overwritten: VRA_2009_06.csv
# 2025-03-02 17:00:10,865 [INFO] Overwritten: VRA_2009_07.csv
# 2025-03-02 17:00:10,904 [INFO] Overwritten: VRA_2009_08.csv
# 2025-03-02 17:00:10,937 [INFO] Overwritten: VRA_2009_09.csv
# 2025-03-02 17:00:10,973 [INFO] Overwritten: VRA_2009_10.csv
# 2025-03-02 17:00:11,007 [INFO] Overwritten: VRA_2009_11.csv
# 2025-03-02 17:00:11,047 [INFO] Overwritten: VRA_2009_12.csv
# 2025-03-02 17:00:11,049 [INFO] CSV processing (overwrite mode) completed.

# %%
# Configure logging
log_file = "csv_processing_2010_beyond.log"
logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# Paths
input_folder = "helium"
output_folder = "test1"

# Ensure output directory exists
os.makedirs(output_folder, exist_ok=True)

def process_csv_files():
    for year in range(2010, 2100):  # From 2010 onwards (assuming future-proofing)
        for month in range(1, 13):  # January to December
            file_name = f"VRA_{year}_{month:02d}.csv"
            file_path = os.path.join(input_folder, file_name)
            
            if os.path.exists(file_path):
                try:
                    # Read CSV with all columns as string using Polars
                    df = pl.read_csv(file_path, separator=";", encoding="utf-8", dtypes={col: pl.Utf8 for col in new_mapping.keys()})

                    # Rename columns based on mapping
                    df = df.rename(new_mapping)

                    # Save the transformed CSV
                    output_path = os.path.join(output_folder, file_name)
                    df.write_csv(output_path, separator=";", include_header=True)

                    logging.info(f"Successfully processed: {file_name}")

                except Exception as e:
                    logging.error(f"Error processing {file_name}: {e}")

# %%
logging.info("CSV processing (2010 and beyond) started.")
process_csv_files()
logging.info("CSV processing (2010 and beyond) completed.")
# Out:
# 2025-03-02 17:04:42,560 [INFO] CSV processing (2010 and beyond) started.
# /tmp/ipykernel_3968/1702756895.py:26: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   df = pl.read_csv(file_path, separator=";", encoding="utf-8", dtypes={col: pl.Utf8 for col in new_mapping.keys()})
# 2025-03-02 17:04:42,702 [INFO] Successfully processed: VRA_2010_01.csv
# 2025-03-02 17:04:42,809 [INFO] Successfully processed: VRA_2010_02.csv
# 2025-03-02 17:04:42,922 [INFO] Successfully processed: VRA_2010_03.csv
# 2025-03-02 17:04:43,031 [INFO] Successfully processed: VRA_2010_04.csv
# 2025-03-02 17:04:43,145 [INFO] Successfully processed: VRA_2010_05.csv
# 2025-03-02 17:04:58,459 [INFO] Successfully processed: VRA_2022_12.csv
# 2025-03-02 17:04:58,538 [INFO] Successfully processed: VRA_2023_01.csv
# 2025-03-02 17:04:58,603 [INFO] Successfully processed: VRA_2023_02.csv
# 2025-03-02 17:04:58,669 [INFO] Successfully processed: VRA_2023_03.csv
# 2025-03-02 17:04:58,737 [INFO] Successfully processed: VRA_2023_04.csv
# 2025-03-02 17:04:58,788 [INFO] Successfully processed: VRA_2023_05.csv
# 2025-03-02 17:04:58,860 [INFO] Successfully processed: VRA_2023_06.csv
# 2025-03-02 17:04:58,939 [INFO] Successfully processed: VRA_2023_07.csv
# 2025-03-02 17:04:59,015 [INFO] Successfully processed: VRA_2023_08.csv
# 2025-03-02 17:04:59,088 [INFO] Successfully processed: VRA_2023_09.csv
# 2025-03-02 17:04:59,165 [INFO] Successfully processed: VRA_2023_10.csv
# 2025-03-02 17:04:59,258 [INFO] Successfully processed: VRA_2023_11.csv
# 2025-03-02 17:04:59,348 [INFO] Successfully processed: VRA_2023_12.csv
# 2025-03-02 17:04:59,426 [INFO] Successfully processed: VRA_2024_01.csv
# 2025-03-02 17:04:59,496 [INFO] Successfully processed: VRA_2024_02.csv
# 2025-03-02 17:04:59,560 [INFO] Successfully processed: VRA_2024_03.csv
# 2025-03-02 17:04:59,631 [INFO] Successfully processed: VRA_2024_04.csv
# 2025-03-02 17:04:59,709 [INFO] Successfully processed: VRA_2024_05.csv
# 2025-03-02 17:04:59,780 [INFO] Successfully processed: VRA_2024_06.csv
# 2025-03-02 17:04:59,885 [INFO] Successfully processed: VRA_2024_07.csv
# 2025-03-02 17:04:59,960 [INFO] Successfully processed: VRA_2024_08.csv
# 2025-03-02 17:05:00,074 [INFO] Successfully processed: VRA_2024_09.csv
# 2025-03-02 17:05:00,187 [INFO] Successfully processed: VRA_2024_10.csv
# 2025-03-02 17:05:00,292 [INFO] Successfully processed: VRA_2024_11.csv
# 2025-03-02 17:05:00,370 [INFO] Successfully processed: VRA_2024_12.csv
# 2025-03-02 17:05:00,462 [INFO] Successfully processed: VRA_2025_01.csv
# 2025-03-02 17:05:00,469 [INFO] CSV processing (2010 and beyond) completed.

# %%
# Configure logging
log_file = "csv_processing_2010_beyond.log"
logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# Folder containing the files
input_folder = "helium"

def process_csv_files():
    for year in range(2010, 2100):  # From 2010 onwards
        for month in range(1, 13):  # January to December
            file_name = f"VRA_{year}_{month:02d}.csv"
            file_path = os.path.join(input_folder, file_name)
            
            if os.path.exists(file_path):
                try:
                    # Read CSV with all columns as string using Polars
                    df = pl.read_csv(file_path, separator=";", encoding="utf-8", dtypes={col: pl.Utf8 for col in new_mapping.keys()})

                    # Rename columns based on mapping
                    df = df.rename(new_mapping)

                    # Overwrite the existing file
                    df.write_csv(file_path, separator=";", include_header=True)

                    logging.info(f"Overwritten: {file_name}")

                except Exception as e:
                    logging.error(f"Error processing {file_name}: {e}")

# %%
logging.info("CSV processing (overwrite mode) started.")
process_csv_files()
logging.info("CSV processing (overwrite mode) completed.")
# Out:
# 2025-03-02 17:07:01,642 [INFO] CSV processing (overwrite mode) started.
# /tmp/ipykernel_3968/4284305960.py:22: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   df = pl.read_csv(file_path, separator=";", encoding="utf-8
# 2025-03-02 17:07:17,929 [INFO] Overwritten: VRA_2022_11.csv
# 2025-03-02 17:07:17,986 [INFO] Overwritten: VRA_2022_12.csv
# 2025-03-02 17:07:18,057 [INFO] Overwritten: VRA_2023_01.csv
# 2025-03-02 17:07:18,117 [INFO] Overwritten: VRA_2023_02.csv
# 2025-03-02 17:07:18,170 [INFO] Overwritten: VRA_2023_03.csv
# 2025-03-02 17:07:18,231 [INFO] Overwritten: VRA_2023_04.csv
# 2025-03-02 17:07:18,288 [INFO] Overwritten: VRA_2023_05.csv
# 2025-03-02 17:07:18,366 [INFO] Overwritten: VRA_2023_06.csv
# 2025-03-02 17:07:18,446 [INFO] Overwritten: VRA_2023_07.csv
# 2025-03-02 17:07:18,526 [INFO] Overwritten: VRA_2023_08.csv
# 2025-03-02 17:07:18,594 [INFO] Overwritten: VRA_2023_09.csv
# 2025-03-02 17:07:18,667 [INFO] Overwritten: VRA_2023_10.csv
# 2025-03-02 17:07:18,761 [INFO] Overwritten: VRA_2023_11.csv
# 2025-03-02 17:07:18,855 [INFO] Overwritten: VRA_2023_12.csv
# 2025-03-02 17:07:18,934 [INFO] Overwritten: VRA_2024_01.csv
# 2025-03-02 17:07:18,996 [INFO] Overwritten: VRA_2024_02.csv
# 2025-03-02 17:07:19,049 [INFO] Overwritten: VRA_2024_03.csv
# 2025-03-02 17:07:19,116 [INFO] Overwritten: VRA_2024_04.csv
# 2025-03-02 17:07:19,188 [INFO] Overwritten: VRA_2024_05.csv
# 2025-03-02 17:07:19,250 [INFO] Overwritten: VRA_2024_06.csv
# 2025-03-02 17:07:19,353 [INFO] Overwritten: VRA_2024_07.csv
# 2025-03-02 17:07:19,425 [INFO] Overwritten: VRA_2024_08.csv
# 2025-03-02 17:07:19,526 [INFO] Overwritten: VRA_2024_09.csv
# 2025-03-02 17:07:19,632 [INFO] Overwritten: VRA_2024_10.csv
# 2025-03-02 17:07:19,733 [INFO] Overwritten: VRA_2024_11.csv
# 2025-03-02 17:07:19,812 [INFO] Overwritten: VRA_2024_12.csv
# 2025-03-02 17:07:19,886 [INFO] Overwritten: VRA_2025_01.csv
# 2025-03-02 17:07:19,890 [INFO] CSV processing (overwrite mode) completed.

# %%
# Configure logging
log_file = "csv_column_check.log"
logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# Folder containing the files
input_folder = "helium"

def check_csv_columns():
    reference_columns = None
    mismatched_files = []

    for file_name in os.listdir(input_folder):
        file_path = os.path.join(input_folder, file_name)

        if file_name.endswith(".csv") and os.path.isfile(file_path):
            try:
                # Read CSV without loading data, only header
                df = pl.read_csv(file_path, separator=";", encoding="utf-8", infer_schema_length=0)
                current_columns = set(df.columns)

                if reference_columns is None:
                    reference_columns = current_columns
                    logging.info(f"Reference columns set from: {file_name}")

                elif reference_columns != current_columns:
                    mismatched_files.append(file_name)
                    logging.warning(f"Column mismatch in {file_name}")

            except Exception as e:
                logging.error(f"Error reading {file_name}: {e}")

    if not mismatched_files:
        logging.info("All files have the same columns (ignoring order).")
    else:
        logging.warning(f"Files with column mismatches: {mismatched_files}")

# %%
    logging.info("CSV column consistency check started.")
    check_csv_columns()
    logging.info("CSV column consistency check completed.")
# Out:
# 2025-03-02 17:09:25,205 [INFO] CSV column consistency check started.
# 2025-03-02 17:09:25,214 [INFO] Reference columns set from: VRA_2002_02.csv
# 2025-03-02 17:09:34,087 [INFO] All files have the same columns (ignoring order).
# 2025-03-02 17:09:34,089 [INFO] CSV column consistency check completed.

# %%
# Configure logging
log_file = "csv_column_ordering.log"
logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# Folder containing the files
input_folder = "helium"

def reorder_csv_columns():
    for file_name in os.listdir(input_folder):
        file_path = os.path.join(input_folder, file_name)

        if file_name.endswith(".csv") and os.path.isfile(file_path):
            try:
                # Read CSV assuming all columns are strings
                df = pl.read_csv(file_path, separator=";", encoding="utf-8", infer_schema_length=0, dtypes={})

                # Convert all columns to string (forcing type consistency)
                df = df.with_columns([df[col].cast(pl.Utf8) for col in df.columns])

                # Ensure all desired columns are present, filling missing with None
                for col in desired_order:
                    if col not in df.columns:
                        df = df.with_columns(pl.lit(None).cast(pl.Utf8).alias(col))

                # Reorder columns
                df = df.select([col for col in desired_order if col in df.columns])

                # Overwrite original file with reordered columns
                df.write_csv(file_path, separator=";", include_header=True)

                logging.info(f"Reordered columns in: {file_name}")

            except Exception as e:
                logging.error(f"Error processing {file_name}: {e}")

# %%
logging.info("CSV column reordering started.")
reorder_csv_columns()
logging.info("CSV column reordering completed.")
# Out:
# 2025-03-02 18:45:45,436 [INFO] CSV column reordering started.
# /tmp/ipykernel_3968/277501735.py:20: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   df = pl.read_csv(file_path, separator=";", encoding="utf-8", infer_schema_length=0, dtypes={})
# 2025-03-02 18:45:45,456 [INFO] Reordered columns in: VRA_2002_02.csv
# 2025-03-02 18:45:45,484 [INFO] Reordered columns in: VRA_2006_03.csv
# 2025-03-02 18:45:45,507 [INFO] Reordered columns in: VRA_2001_12.csv
# 2025-03-02 18:45:45,556 [INFO] Reordered columns in: VRA_2023_02.csv
# 2025-03-02 18:45:45,574 [INFO] Reordered columns in: VRA_2004_11.csv
# 2025-03-02 18:45:45,592 [INFO] Reordered columns in: VRA_2008_06.csv
# 2025-03-02 18:45:45,607 [INFO] Reordered columns in: VRA_2004_05.csv
# 2025-03-02 18:45:45,692 [INFO] Reordered columns in: VRA_2010_06.csv
# 2025-03-02 18:45:45,750 [INFO] Reordered columns in: VRA_2024_04.csv
# 2025-03-02 18:45:45,845 [INFO] Reordered columns in: VRA_2014_09.csv
# 2025-03-02 18:45:45,866 [INFO] Reordered columns in: VRA_2006_05.csv
# 2025-03-02 18:45:45,946 [INFO] Reordered columns in: VRA_2016_10.csv
# 2025-03-02 18:45:45,965 [INFO] Reordered columns in: VRA_2007_02.csv
# 2025-03-02 18:45:46,010 [INFO] Reordered columns in: VRA_2022_04.csv
# 2025-03-02 18:45:46,025 [INFO] Reordered columns in: VRA_2006_11.csv
# 2025-03-02 18:45:46,081 [INFO] Reordered columns in: VRA_2020_02.csv
# 2025-03-02 18:45:46,101 [INFO] Reordered columns in: VRA_2009_01.csv
# 2025-03-02 18:45:46,174 [INFO] Reordered columns in: VRA_2010_02.csv
# 2025-03-02 18:45:46,273 [INFO] Reordered columns in: VRA_2014_05.csv
# 2025-03-02 18:45:46,291 [INFO] Reordered columns in: VRA_2006_02.csv
# 2025-03-02 18:45:46,305 [INFO] Reordered columns in: VRA_2005_04.csv
# 2025-03-02 18:45:46,383 [INFO] Reordered columns in: VRA_2017_10.csv
# 2025-03-02 18:45:46,414 [INFO] Reordered columns in: VRA_2020_11.csv
# 2025-03-02 18:45:46,490 [INFO] Reordered columns in: VRA_2018_02.csv
# 2025-03-02 18:45:46,584 [INFO] Reordered columns in: VRA_2014_03.csv
# 2025-03-02 18:45:46,658 [INFO] Reordered columns in: VRA_2017_09.csv
# 2025-03-02 18:45:46,675 [INFO] Reordered columns in: VRA_2003_09.csv
# 2025-03-02 18:45:46,723 [INFO] Reordered columns in: VRA_2021_10.csv
# 2025-03-02 18:45:46,805 [INFO] Reordered columns in: VRA_2017_12.csv
# 2025-03-02 18:45:46,874 [INFO] Reordered columns in: VRA_2018_12.csv
# 2025-03-02 18:45:46,969 [INFO] Reordered columns in: VRA_2011_03.csv
# 2025-03-02 18:45:47,061 [INFO] Reordered columns in: VRA_2013_04.csv
# 2025-03-02 18:45:47,159 [INFO] Reordered columns in: VRA_2013_07.csv
# 2025-03-02 18:45:47,241 [INFO] Reordered columns in: VRA_2017_11.csv
# 2025-03-02 18:45:47,295 [INFO] Reordered columns in: VRA_2019_05.csv
# 2025-03-02 18:45:47,385 [INFO] Reordered columns in: VRA_2011_04.csv
# 2025-03-02 18:45:47,485 [INFO] Reordered columns in: VRA_2012_03.csv
# 2025-03-02 18:45:47,578 [INFO] Reordered columns in: VRA_2013_10.csv
# 2025-03-02 18:45:47,666 [INFO] Reordered columns in: VRA_2015_11.csv
# 2025-03-02 18:45:47,760 [INFO] Reordered columns in: VRA_2011_08.csv
# 2025-03-02 18:45:47,824 [INFO] Reordered columns in: VRA_2019_01.csv
# 2025-03-02 18:45:47,879 [INFO] Reordered columns in: VRA_2023_10.csv
# 2025-03-02 18:45:47,977 [INFO] Reordered columns in: VRA_2015_07.csv
# 2025-03-02 18:45:47,993 [INFO] Reordered columns in: VRA_2003_07.csv
# 2025-03-02 18:45:48,009 [INFO] Reordered columns in: VRA_2005_02.csv
# 2025-03-02 18:45:48,084 [INFO] Reordered columns in: VRA_2017_04.csv
# 2025-03-02 18:45:48,137 [INFO] Reordered columns in: VRA_2022_07.csv
# 2025-03-02 18:45:48,154 [INFO] Reordered columns in: VRA_2004_08.csv
# 2025-03-02 18:45:48,236 [INFO] Reordered columns in: VRA_2017_07.csv
# 2025-03-02 18:45:48,253 [INFO] Reordered columns in: VRA_2004_04.csv
# 2025-03-02 18:45:48,290 [INFO] Reordered columns in: VRA_2020_12.csv
# 2025-03-02 18:45:48,310 [INFO] Reordered columns in: VRA_2007_11.csv
# 2025-03-02 18:45:48,356 [INFO] Reordered columns in: VRA_2020_03.csv
# 2025-03-02 18:45:48,374 [INFO] Reordered columns in: VRA_2005_12.csv
# 2025-03-02 18:45:48,393 [INFO] Reordered columns in: VRA_2003_01.csv
# 2025-03-02 18:45:48,410 [INFO] Reordered columns in: VRA_2002_03.csv
# 2025-03-02 18:45:48,460 [INFO] Reordered columns in: VRA_2024_05.csv
# 2025-03-02 18:45:48,536 [INFO] Reordered columns in: VRA_2017_03.csv
# 2025-03-02 18:45:48,556 [INFO] Reordered columns in: VRA_2006_10.csv
# 2025-03-02 18:45:48,635 [INFO] Reordered columns in: VRA_2010_03.csv
# 2025-03-02 18:45:48,691 [INFO] Reordered columns in: VRA_2018_04.csv
# 2025-03-02 18:45:48,787 [INFO] Reordered columns in: VRA_2012_08.csv
# 2025-03-02 18:45:48,871 [INFO] Reordered columns in: VRA_2017_01.csv
# 2025-03-02 18:45:48,926 [INFO] Reordered columns in: VRA_2023_03.csv
# 2025-03-02 18:45:49,007 [INFO] Reordered columns in: VRA_2010_04.csv
# 2025-03-02 18:45:49,113 [INFO] Reordered columns in: VRA_2012_01.csv
# 2025-03-02 18:45:49,200 [INFO] Reordered columns in: VRA_2011_02.csv
# 2025-03-02 18:45:49,221 [INFO] Reordered columns in: VRA_2002_01.csv
# 2025-03-02 18:45:49,240 [INFO] Reordered columns in: VRA_2009_08.csv
# 2025-03-02 18:45:49,256 [INFO] Reordered columns in: VRA_2005_03.csv
# 2025-03-02 18:45:49,301 [INFO] Reordered columns in: VRA_2018_03.csv
# 2025-03-02 18:45:49,320 [INFO] Reordered columns in: VRA_2003_04.csv
# 2025-03-02 18:45:49,337 [INFO] Reordered columns in: VRA_2002_09.csv
# 2025-03-02 18:45:49,388 [INFO] Reordered columns in: VRA_2024_12.csv
# 2025-03-02 18:45:49,464 [INFO] Reordered columns in: VRA_2016_08.csv
# 2025-03-02 18:45:49,514 [INFO] Reordered columns in: VRA_2023_04.csv
# 2025-03-02 18:45:49,566 [INFO] Reordered columns in: VRA_2018_05.csv
# 2025-03-02 18:45:49,623 [INFO] Reordered columns in: VRA_2024_01.csv
# 2025-03-02 18:45:49,683 [INFO] Reordered columns in: VRA_2019_03.csv
# 2025-03-02 18:45:49,703 [INFO] Reordered columns in: VRA_2000_04.csv
# 2025-03-02 18:45:49,720 [INFO] Reordered columns in: VRA_2002_11.csv
# 2025-03-02 18:45:49,795 [INFO] Reordered columns in: VRA_2016_06.csv
# 2025-03-02 18:45:49,817 [INFO] Reordered columns in: VRA_2020_08.csv
# 2025-03-02 18:45:49,837 [INFO] Reordered columns in: VRA_2007_07.csv
# 2025-03-02 18:45:49,911 [INFO] Reordered columns in: VRA_2016_05.csv
# 2025-03-02 18:45:49,940 [INFO] Reordered columns in: VRA_2020_10.csv
# 2025-03-02 18:45:50,013 [INFO] Reordered columns in: VRA_2024_11.csv
# 2025-03-02 18:45:50,033 [INFO] Reordered columns in: VRA_2001_06.csv
# 2025-03-02 18:45:50,139 [INFO] Reordered columns in: VRA_2011_11.csv
# 2025-03-02 18:45:50,242 [INFO] Reordered columns in: VRA_2012_05.csv
# 2025-03-02 18:45:50,343 [INFO] Reordered columns in: VRA_2012_07.csv
# 2025-03-02 18:45:50,362 [INFO] Reordered columns in: VRA_2000_10.csv
# 2025-03-02 18:45:50,455 [INFO] Reordered columns in: VRA_2016_01.csv
# 2025-03-02 18:45:50,545 [INFO] Reordered columns in: VRA_2013_11.csv
# 2025-03-02 18:45:50,601 [INFO] Reordered columns in: VRA_2024_03.csv
# 2025-03-02 18:45:50,692 [INFO] Reordered columns in: VRA_2010_11.csv
# 2025-03-02 18:45:50,713 [INFO] Reordered columns in: VRA_2008_03.csv
# 2025-03-02 18:45:50,759 [INFO] Reordered columns in: VRA_2022_08.csv
# 2025-03-02 18:45:50,778 [INFO] Reordered columns in: VRA_2021_04.csv
# 2025-03-02 18:45:50,793 [INFO] Reordered columns in: VRA_2003_12.csv
# 2025-03-02 18:45:50,884 [INFO] Reordered columns in: VRA_2013_06.csv
# 2025-03-02 18:45:50,904 [INFO] Reordered columns in: VRA_2001_01.csv
# 2025-03-02 18:45:50,966 [INFO] Reordered columns in: VRA_2020_01.csv
# 2025-03-02 18:45:50,988 [INFO] Reordered columns in: VRA_2002_06.csv
# 2025-03-02 18:45:51,007 [INFO] Reordered columns in: VRA_2000_12.csv
# 2025-03-02 18:45:51,099 [INFO] Reordered columns in: VRA_2015_02.csv
# 2025-03-02 18:45:51,117 [INFO] Reordered columns in: VRA_2003_11.csv
# 2025-03-02 18:45:51,162 [INFO] Reordered columns in: VRA_2021_12.csv
# 2025-03-02 18:45:51,196 [INFO] Reordered columns in: VRA_2021_01.csv
# 2025-03-02 18:45:51,213 [INFO] Reordered columns in: VRA_2005_09.csv
# 2025-03-02 18:45:51,268 [INFO] Reordered columns in: VRA_2019_02.csv
# 2025-03-02 18:45:51,286 [INFO] Reordered columns in: VRA_2004_01.csv
# 2025-03-02 18:45:51,304 [INFO] Reordered columns in: VRA_2009_05.csv
# 2025-03-02 18:45:51,331 [INFO] Reordered columns in: VRA_2021_03.csv
# 2025-03-02 18:45:51,346 [INFO] Reordered columns in: VRA_2005_05.csv
# 2025-03-02 18:45:51,365 [INFO] Reordered columns in: VRA_2002_05.csv
# 2025-03-02 18:45:51,415 [INFO] Reordered columns in: VRA_2022_11.csv
# 2025-03-02 18:45:51,433 [INFO] Reordered columns in: VRA_2008_08.csv
# 2025-03-02 18:45:51,530 [INFO] Reordered columns in: VRA_2011_05.csv
# 2025-03-02 18:45:51,569 [INFO] Reordered columns in: VRA_2021_07.csv
# 2025-03-02 18:45:51,590 [INFO] Reordered columns in: VRA_2008_12.csv
# 2025-03-02 18:45:51,606 [INFO] Reordered columns in: VRA_2001_02.csv
# 2025-03-02 18:45:51,623 [INFO] Reordered columns in: VRA_2000_06.csv
# 2025-03-02 18:45:51,638 [INFO] Reordered columns in: VRA_2003_06.csv
# 2025-03-02 18:45:51,658 [INFO] Reordered columns in: VRA_2009_02.csv
# 2025-03-02 18:45:51,675 [INFO] Reordered columns in: VRA_2000_03.csv
# 2025-03-02 18:45:51,693 [INFO] Reordered columns in: VRA_2008_04.csv
# 2025-03-02 18:45:51,705 [INFO] Reordered columns in: VRA_2020_06.csv
# 2025-03-02 18:45:51,795 [INFO] Reordered columns in: VRA_2012_09.csv
# 2025-03-02 18:45:51,815 [INFO] Reordered columns in: VRA_2006_01.csv
# 2025-03-02 18:45:51,927 [INFO] Reordered columns in: VRA_2013_03.csv
# 2025-03-02 18:45:51,950 [INFO] Reordered columns in: VRA_2007_01.csv
# 2025-03-02 18:45:51,968 [INFO] Reordered columns in: VRA_2006_07.csv
# 2025-03-02 18:45:52,018 [INFO] Reordered columns in: VRA_2024_02.csv
# 2025-03-02 18:45:52,069 [INFO] Reordered columns in: VRA_2019_11.csv
# 2025-03-02 18:45:52,170 [INFO] Reordered columns in: VRA_2014_08.csv
# 2025-03-02 18:45:52,187 [INFO] Reordered columns in: VRA_2020_07.csv
# 2025-03-02 18:45:52,235 [INFO] Reordered columns in: VRA_2022_01.csv
# 2025-03-02 18:45:52,332 [INFO] Reordered columns in: VRA_2011_12.csv
# 2025-03-02 18:45:52,336 [INFO] Reordered columns in: VRA_2014_06.csv
# 2025-03-02 18:45:52,427 [INFO] Reordered columns in: VRA_2014_11.csv
# 2025-03-02 18:45:52,447 [INFO] Reordered columns in: VRA_2001_04.csv
# 2025-03-02 18:45:52,531 [INFO] Reordered columns in: VRA_2017_05.csv
# 2025-03-02 18:45:52,630 [INFO] Reordered columns in: VRA_2012_04.csv
# 2025-03-02 18:45:52,712 [INFO] Reordered columns in: VRA_2016_11.csv
# 2025-03-02 18:45:52,736 [INFO] Reordered columns in: VRA_2007_06.csv
# 2025-03-02 18:45:52,788 [INFO] Reordered columns in: VRA_2023_09.csv
# 2025-03-02 18:45:52,832 [INFO] Reordered columns in: VRA_2022_03.csv
# 2025-03-02 18:45:52,925 [INFO] Reordered columns in: VRA_2010_07.csv
# 2025-03-02 18:45:52,946 [INFO] Reordered columns in: VRA_2001_07.csv
# 2025-03-02 18:45:53,004 [INFO] Reordered columns in: VRA_2022_09.csv
# 2025-03-02 18:45:53,077 [INFO] Reordered columns in: VRA_2017_02.csv
# 2025-03-02 18:45:53,127 [INFO] Reordered columns in: VRA_2022_10.csv
# 2025-03-02 18:45:53,210 [INFO] Reordered columns in: VRA_2010_05.csv
# 2025-03-02 18:45:53,233 [INFO] Reordered columns in: VRA_2009_07.csv
# 2025-03-02 18:45:53,252 [INFO] Reordered columns in: VRA_2008_11.csv
# 2025-03-02 18:45:53,269 [INFO] Reordered columns in: VRA_2007_03.csv
# 2025-03-02 18:45:53,369 [INFO] Reordered columns in: VRA_2015_09.csv
# 2025-03-02 18:45:53,388 [INFO] Reordered columns in: VRA_2004_10.csv
# 2025-03-02 18:45:53,477 [INFO] Reordered columns in: VRA_2010_08.csv
# 2025-03-02 18:45:53,537 [INFO] Reordered columns in: VRA_2024_08.csv
# 2025-03-02 18:45:53,558 [INFO] Reordered columns in: VRA_2002_10.csv
# 2025-03-02 18:45:53,605 [INFO] Reordered columns in: VRA_2022_05.csv
# 2025-03-02 18:45:53,695 [INFO] Reordered columns in: VRA_2011_06.csv
# 2025-03-02 18:45:53,715 [INFO] Reordered columns in: VRA_2000_11.csv
# 2025-03-02 18:45:53,797 [INFO] Reordered columns in: VRA_2016_07.csv
# 2025-03-02 18:45:53,817 [INFO] Reordered columns in: VRA_2002_08.csv
# 2025-03-02 18:45:53,910 [INFO] Reordered columns in: VRA_2015_06.csv
# 2025-03-02 18:45:53,966 [INFO] Reordered columns in: VRA_2023_08.csv
# 2025-03-02 18:45:53,993 [INFO] Reordered columns in: VRA_2009_12.csv
# 2025-03-02 18:45:54,050 [INFO] Reordered columns in: VRA_2022_12.csv
# 2025-03-02 18:45:54,071 [INFO] Reordered columns in: VRA_2003_03.csv
# 2025-03-02 18:45:54,163 [INFO] Reordered columns in: VRA_2011_01.csv
# 2025-03-02 18:45:54,219 [INFO] Reordered columns in: VRA_2019_04.csv
# 2025-03-02 18:45:54,318 [INFO] Reordered columns in: VRA_2010_10.csv
# 2025-03-02 18:45:54,346 [INFO] Reordered columns in: VRA_2021_06.csv
# 2025-03-02 18:45:54,365 [INFO] Reordered columns in: VRA_2009_06.csv
# 2025-03-02 18:45:54,382 [INFO] Reordered columns in: VRA_2000_09.csv
# 2025-03-02 18:45:54,384 [INFO] Reordered columns in: VRA_2014_07.csv
# 2025-03-02 18:45:54,476 [INFO] Reordered columns in: VRA_2011_10.csv
# 2025-03-02 18:45:54,540 [INFO] Reordered columns in: VRA_2023_11.csv
# 2025-03-02 18:45:54,558 [INFO] Reordered columns in: VRA_2001_10.csv
# 2025-03-02 18:45:54,613 [INFO] Reordered columns in: VRA_2019_10.csv
# 2025-03-02 18:45:54,635 [INFO] Reordered columns in: VRA_2007_12.csv
# 2025-03-02 18:45:54,652 [INFO] Reordered columns in: VRA_2005_08.csv
# 2025-03-02 18:45:54,673 [INFO] Reordered columns in: VRA_2020_09.csv
# 2025-03-02 18:45:54,688 [INFO] Reordered columns in: VRA_2004_09.csv
# 2025-03-02 18:45:54,705 [INFO] Reordered columns in: VRA_2008_05.csv
# 2025-03-02 18:45:54,716 [INFO] Reordered columns in: VRA_2020_05.csv
# 2025-03-02 18:45:54,822 [INFO] Reordered columns in: VRA_2014_12.csv
# 2025-03-02 18:45:54,881 [INFO] Reordered columns in: VRA_2019_07.csv
# 2025-03-02 18:45:54,905 [INFO] Reordered columns in: VRA_2009_10.csv
# 2025-03-02 18:45:54,987 [INFO] Reordered columns in: VRA_2017_08.csv
# 2025-03-02 18:45:55,008 [INFO] Reordered columns in: VRA_2000_02.csv
# 2025-03-02 18:45:55,026 [INFO] Reordered columns in: VRA_2006_08.csv
# 2025-03-02 18:45:55,118 [INFO] Reordered columns in: VRA_2015_10.csv
# 2025-03-02 18:45:55,192 [INFO] Reordered columns in: VRA_2019_06.csv
# 2025-03-02 18:45:55,210 [INFO] Reordered columns in: VRA_2003_10.csv
# 2025-03-02 18:45:55,226 [INFO] Reordered columns in: VRA_2005_01.csv
# 2025-03-02 18:45:55,255 [INFO] Reordered columns in: VRA_2021_02.csv
# 2025-03-02 18:45:55,270 [INFO] Reordered columns in: VRA_2003_08.csv
# 2025-03-02 18:45:55,365 [INFO] Reordered columns in: VRA_2013_05.csv
# 2025-03-02 18:45:55,385 [INFO] Reordered columns in: VRA_2001_03.csv
# 2025-03-02 18:45:55,442 [INFO] Reordered columns in: VRA_2023_05.csv
# 2025-03-02 18:45:55,485 [INFO] Reordered columns in: VRA_2021_11.csv
# 2025-03-02 18:45:55,503 [INFO] Reordered columns in: VRA_2008_02.csv
# 2025-03-02 18:45:57,554 [INFO] Reordered columns in: VRA_2024_10.csv
# 2025-03-02 18:45:57,616 [INFO] Reordered columns in: VRA_2023_07.csv
# 2025-03-02 18:45:57,704 [INFO] Reordered columns in: VRA_2013_02.csv
# 2025-03-02 18:45:57,762 [INFO] Reordered columns in: VRA_2018_10.csv
# 2025-03-02 18:45:57,821 [INFO] Reordered columns in: VRA_2023_01.csv
# 2025-03-02 18:45:57,911 [INFO] Reordered columns in: VRA_2011_09.csv
# 2025-03-02 18:45:57,932 [INFO] Reordered columns in: VRA_2007_04.csv
# 2025-03-02 18:45:57,950 [INFO] Reordered columns in: VRA_2001_05.csv
# 2025-03-02 18:45:58,007 [INFO] Reordered columns in: VRA_2025_01.csv
# 2025-03-02 18:45:58,016 [INFO] Reordered columns in: VRA_2020_04.csv
# 2025-03-02 18:45:58,114 [INFO] Reordered columns in: VRA_2013_01.csv
# 2025-03-02 18:45:58,135 [INFO] Reordered columns in: VRA_2003_02.csv
# 2025-03-02 18:45:58,223 [INFO] Reordered columns in: VRA_2024_07.csv
# 2025-03-02 18:45:58,329 [INFO] Reordered columns in: VRA_2015_01.csv
# 2025-03-02 18:45:58,427 [INFO] Reordered columns in: VRA_2013_08.csv
# 2025-03-02 18:45:58,480 [INFO] Reordered columns in: VRA_2024_06.csv
# 2025-03-02 18:45:58,557 [INFO] Reordered columns in: VRA_2017_06.csv
# 2025-03-02 18:45:58,653 [INFO] Reordered columns in: VRA_2016_02.csv
# 2025-03-02 18:45:58,709 [INFO] Reordered columns in: VRA_2019_09.csv
# 2025-03-02 18:45:58,729 [INFO] Reordered columns in: VRA_2005_10.csv
# 2025-03-02 18:45:58,828 [INFO] Reordered columns in: VRA_2015_03.csv
# 2025-03-02 18:45:58,885 [INFO] Reordered columns in: VRA_2018_11.csv
# 2025-03-02 18:45:58,908 [INFO] Reordered columns in: VRA_2002_07.csv
# 2025-03-02 18:45:58,956 [INFO] Reordered columns in: VRA_2023_06.csv
# 2025-03-02 18:45:59,006 [INFO] Reordered columns in: VRA_2018_06.csv
# 2025-03-02 18:45:59,023 [INFO] Reordered columns in: VRA_2006_04.csv
# 2025-03-02 18:45:59,114 [INFO] Reordered columns in: VRA_2012_02.csv
# 2025-03-02 18:45:59,209 [INFO] Reordered columns in: VRA_2014_04.csv
# 2025-03-02 18:45:59,227 [INFO] Reordered columns in: VRA_2005_06.csv
# 2025-03-02 18:45:59,246 [INFO] Reordered columns in: VRA_2001_08.csv
# 2025-03-02 18:45:59,263 [INFO] Reordered columns in: VRA_2008_10.csv
# 2025-03-02 18:45:59,351 [INFO] Reordered columns in: VRA_2016_04.csv
# 2025-03-02 18:45:59,439 [INFO] Reordered columns in: VRA_2010_09.csv
# 2025-03-02 18:45:59,497 [INFO] Reordered columns in: VRA_2018_09.csv
# 2025-03-02 18:45:59,517 [INFO] Reordered columns in: VRA_2009_09.csv
# 2025-03-02 18:45:59,535 [INFO] Reordered columns in: VRA_2008_07.csv
# 2025-03-02 18:45:59,623 [INFO] Reordered columns in: VRA_2016_12.csv
# 2025-03-02 18:45:59,725 [INFO] Reordered columns in: VRA_2015_04.csv
# 2025-03-02 18:45:59,819 [INFO] Reordered columns in: VRA_2012_11.csv
# 2025-03-02 18:45:59,879 [INFO] Reordered columns in: VRA_2019_12.csv
# 2025-03-02 18:45:59,899 [INFO] Reordered columns in: VRA_2000_01.csv
# 2025-03-02 18:45:59,918 [INFO] Reordered columns in: VRA_2009_11.csv
# 2025-03-02 18:46:00,016 [INFO] Reordered columns in: VRA_2014_10.csv
# 2025-03-02 18:46:00,038 [INFO] Reordered columns in: VRA_2008_09.csv
# 2025-03-02 18:46:00,135 [INFO] Reordered columns in: VRA_2012_10.csv
# 2025-03-02 18:46:00,188 [INFO] Reordered columns in: VRA_2022_02.csv
# 2025-03-02 18:46:00,206 [INFO] Reordered columns in: VRA_2006_06.csv
# 2025-03-02 18:46:00,299 [INFO] Reordered columns in: VRA_2012_12.csv
# 2025-03-02 18:46:00,321 [INFO] Reordered columns in: VRA_2007_10.csv
# 2025-03-02 18:46:00,337 [INFO] Reordered columns in: VRA_2004_07.csv
# 2025-03-02 18:46:00,355 [INFO] Reordered columns in: VRA_2005_07.csv
# 2025-03-02 18:46:00,373 [INFO] Reordered columns in: VRA_2004_12.csv
# 2025-03-02 18:46:00,391 [INFO] Reordered columns in: VRA_2007_08.csv
# 2025-03-02 18:46:00,435 [INFO] Reordered columns in: VRA_2022_06.csv
# 2025-03-02 18:46:00,530 [INFO] Reordered columns in: VRA_2010_01.csv
# 2025-03-02 18:46:00,550 [INFO] Reordered columns in: VRA_2002_04.csv
# 2025-03-02 18:46:00,565 [INFO] Reordered columns in: VRA_2004_06.csv
# 2025-03-02 18:46:00,581 [INFO] Reordered columns in: VRA_2004_03.csv
# 2025-03-02 18:46:00,584 [INFO] CSV column reordering completed.

# %% [markdown]
# # Overview
#
# This script automatically adds "ano" (year) and "mes" (month) columns to CSV files stored in the "helium" folder. It extracts these values directly from the filename, which is expected to be in the format "VRA_YYYY_MM.csv", ensuring your data carries its own temporal markers without any manual fuss.
#
# ## What it does
#
# - **Logging configuration:**
#   Sets up logging to record actions and errors in "csv_add_ano_mes.log" with clear timestamps and log levels. Nothing slips past this log.
#
# - **File scanning and pattern matching:**
#   Iterates over all files in the input folder, using a regex to identify CSV files that follow the "VRA_YYYY_MM.csv" naming convention. Only valid files get processed.
#
# - **CSV processing:**
#   For each matching file:
#   - Extracts the year ("ano") and month ("mes") from the filename.
#   - Reads the CSV file with Polars, treating all columns as strings.
#   - Converts every column in the file to string format for uniformity.
#   - Adds new "ano" and "mes" columns populated with the extracted values.
#   - Overwrites the original CSV with the updated data.
#
# - **Error handling:**
#   Logs successful modifications as well as any errors encountered during processing, ensuring you're always informed about the script's performance.
#
# ## Why it does it
#
# Because manually inserting year and month data into every CSV file is a waste of time. This script enforces consistency and ensures your datasets are self-contained and ready for analysis, because maybe, just maybe, that was exactly the kind of task Salah was doing againt PSG, being so loaded with this task that he forgot to play.

# %%
# Configure logging
log_file = "csv_add_ano_mes.log"
logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# Folder containing the files
input_folder = "helium"

def add_ano_mes_columns():
    pattern = re.compile(r"VRA_(\d{4})_(\d{2})\.csv")  # Regex to extract year and month

    for file_name in os.listdir(input_folder):
        file_path = os.path.join(input_folder, file_name)

        match = pattern.match(file_name)
        if match and file_name.endswith(".csv") and os.path.isfile(file_path):
            try:
                # Extract year and month
                ano, mes = match.groups()

                # Read CSV assuming all columns are strings
                df = pl.read_csv(file_path, separator=";", encoding="utf-8", infer_schema_length=0, dtypes={})

                # Convert all columns to string
                df = df.with_columns([df[col].cast(pl.Utf8) for col in df.columns])

                # Add "ano" and "mes" columns
                df = df.with_columns(
                    pl.lit(ano).cast(pl.Utf8).alias("ano"),
                    pl.lit(mes).cast(pl.Utf8).alias("mes")
                )

                # Overwrite the original CSV
                df.write_csv(file_path, separator=";", include_header=True)

                logging.info(f"Added 'ano' and 'mes' to: {file_name}")

            except Exception as e:
                logging.error(f"Error processing {file_name}: {e}")

# %%
logging.info("Adding 'ano' and 'mes' columns started.")
add_ano_mes_columns()
logging.info("Adding 'ano' and 'mes' columns completed.")
# Out:
# 2025-03-02 18:50:06,460 [INFO] Adding 'ano' and 'mes' columns started.
# /tmp/ipykernel_3968/1034229512.py:26: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   df = pl.read_csv(file_path, separator=";", encoding="utf-8", infer_schema_length=0, dtypes={})
# 2025-03-02 18:50:06,493 [INFO] Added 'ano' and 'mes' to: VRA_2002_02.csv
# 2025-03-02 18:50:06,519 [INFO] Added 'ano' and 'mes' to: VRA_2006_03.csv
# 2025-03-02 18:50:06,543 [INFO] Added 'ano' and 'mes' to: VRA_2001_12.csv
# 2025-03-02 18:50:06,600 [INFO] Added 'ano' and 'mes' to: VRA_2023_02.csv
# 2025-03-02 18:50:06,621 [INFO] Added 'ano' and 'mes' to: VRA_2004_11.csv
# 2025-03-02 18:50:06,644 [INFO] Added 'ano' and 'mes' to: VRA_2008_06.csv
# 2025-03-02 18:50:06,665 [INFO] Added 'ano' and 'mes' to: VRA_2004_05.csv
# 2025-03-02 18:50:06,754 [INFO] Added 'ano' and 'mes' to: VRA_2010_06.csv
# 2025-03-02 18:50:06,815 [INFO] Added 'ano' and 'mes' to: VRA_2024_04.csv
# 2025-03-02 18:50:06,913 [INFO] Added 'ano' and 'mes' to: VRA_2014_09.csv
# 2025-03-02 18:50:06,937 [INFO] Added 'ano' and 'mes' to: VRA_2006_05.csv
# 2025-03-02 18:50:07,017 [INFO] Added 'ano' and 'mes' to: VRA_2016_10.csv
# 2025-03-02 18:50:07,041 [INFO] Added 'ano' and 'mes' to: VRA_2007_02.csv
# 2025-03-02 18:50:07,090 [INFO] Added 'ano' and 'mes' to: VRA_2022_04.csv
# 2025-03-02 18:50:07,110 [INFO] Added 'ano' and 'mes' to: VRA_2006_11.csv
# 2025-03-02 18:50:07,169 [INFO] Added 'ano' and 'mes' to: VRA_2020_02.csv
# 2025-03-02 18:50:07,196 [INFO] Added 'ano' and 'mes' to: VRA_2009_01.csv
# 2025-03-02 18:50:07,276 [INFO] Added 'ano' and 'mes' to: VRA_2010_02.csv
# 2025-03-02 18:50:07,375 [INFO] Added 'ano' and 'mes' to: VRA_2014_05.csv
# 2025-03-02 18:50:07,396 [INFO] Added 'ano' and 'mes' to: VRA_2006_02.csv
# 2025-03-02 18:50:07,415 [INFO] Added 'ano' and 'mes' to: VRA_2005_04.csv
# 2025-03-02 18:50:07,497 [INFO] Added 'ano' and 'mes' to: VRA_2017_10.csv
# 2025-03-02 18:50:07,532 [INFO] Added 'ano' and 'mes' to: VRA_2020_11.csv
# 2025-03-02 18:50:07,610 [INFO] Added 'ano' and 'mes' to: VRA_2018_02.csv
# 2025-03-02 18:50:07,708 [INFO] Added 'ano' and 'mes' to: VRA_2014_03.csv
# 2025-03-02 18:50:07,787 [INFO] Added 'ano' and 'mes' to: VRA_2017_09.csv
# 2025-03-02 18:50:07,807 [INFO] Added 'ano' and 'mes' to: VRA_2003_09.csv
# 2025-03-02 18:50:07,877 [INFO] Added 'ano' and 'mes' to: VRA_2021_10.csv
# 2025-03-02 18:50:07,969 [INFO] Added 'ano' and 'mes' to: VRA_2017_12.csv
# 2025-03-02 18:50:08,035 [INFO] Added 'ano' and 'mes' to: VRA_2018_12.csv
# 2025-03-02 18:50:08,133 [INFO] Added 'ano' and 'mes' to: VRA_2011_03.csv
# 2025-03-02 18:50:08,228 [INFO] Added 'ano' and 'mes' to: VRA_2013_04.csv
# 2025-03-02 18:50:08,335 [INFO] Added 'ano' and 'mes' to: VRA_2013_07.csv
# 2025-03-02 18:50:08,421 [INFO] Added 'ano' and 'mes' to: VRA_2017_11.csv
# 2025-03-02 18:50:08,477 [INFO] Added 'ano' and 'mes' to: VRA_2019_05.csv
# 2025-03-02 18:50:08,570 [INFO] Added 'ano' and 'mes' to: VRA_2011_04.csv
# 2025-03-02 18:50:08,670 [INFO] Added 'ano' and 'mes' to: VRA_2012_03.csv
# 2025-03-02 18:50:08,768 [INFO] Added 'ano' and 'mes' to: VRA_2013_10.csv
# 2025-03-02 18:50:08,861 [INFO] Added 'ano' and 'mes' to: VRA_2015_11.csv
# 2025-03-02 18:50:08,963 [INFO] Added 'ano' and 'mes' to: VRA_2011_08.csv
# 2025-03-02 18:50:09,038 [INFO] Added 'ano' and 'mes' to: VRA_2019_01.csv
# 2025-03-02 18:50:09,098 [INFO] Added 'ano' and 'mes' to: VRA_2023_10.csv
# 2025-03-02 18:50:09,204 [INFO] Added 'ano' and 'mes' to: VRA_2015_07.csv
# 2025-03-02 18:50:09,223 [INFO] Added 'ano' and 'mes' to: VRA_2003_07.csv
# 2025-03-02 18:50:09,243 [INFO] Added 'ano' and 'mes' to: VRA_2005_02.csv
# 2025-03-02 18:50:09,324 [INFO] Added 'ano' and 'mes' to: VRA_2017_04.csv
# 2025-03-02 18:50:09,377 [INFO] Added 'ano' and 'mes' to: VRA_2022_07.csv
# 2025-03-02 18:50:09,396 [INFO] Added 'ano' and 'mes' to: VRA_2004_08.csv
# 2025-03-02 18:50:09,486 [INFO] Added 'ano' and 'mes' to: VRA_2017_07.csv
# 2025-03-02 18:50:09,506 [INFO] Added 'ano' and 'mes' to: VRA_2004_04.csv
# 2025-03-02 18:50:09,545 [INFO] Added 'ano' and 'mes' to: VRA_2020_12.csv
# 2025-03-02 18:50:09,568 [INFO] Added 'ano' and 'mes' to: VRA_2007_11.csv
# 2025-03-02 18:50:09,612 [INFO] Added 'ano' and 'mes' to: VRA_2020_03.csv
# 2025-03-02 18:50:09,634 [INFO] Added 'ano' and 'mes' to: VRA_2005_12.csv
# 2025-03-02 18:50:09,657 [INFO] Added 'ano' and 'mes' to: VRA_2003_01.csv
# 2025-03-02 18:50:09,678 [INFO] Added 'ano' and 'mes' to: VRA_2002_03.csv
# 2025-03-02 18:50:09,732 [INFO] Added 'ano' and 'mes' to: VRA_2024_05.csv
# 2025-03-02 18:50:09,822 [INFO] Added 'ano' and 'mes' to: VRA_2017_03.csv
# 2025-03-02 18:50:09,845 [INFO] Added 'ano' and 'mes' to: VRA_2006_10.csv
# 2025-03-02 18:50:09,927 [INFO] Added 'ano' and 'mes' to: VRA_2010_03.csv
# 2025-03-02 18:50:09,984 [INFO] Added 'ano' and 'mes' to: VRA_2018_04.csv
# 2025-03-02 18:50:10,084 [INFO] Added 'ano' and 'mes' to: VRA_2012_08.csv
# 2025-03-02 18:50:10,173 [INFO] Added 'ano' and 'mes' to: VRA_2017_01.csv
# 2025-03-02 18:50:10,231 [INFO] Added 'ano' and 'mes' to: VRA_2023_03.csv
# 2025-03-02 18:50:10,319 [INFO] Added 'ano' and 'mes' to: VRA_2010_04.csv
# 2025-03-02 18:50:10,430 [INFO] Added 'ano' and 'mes' to: VRA_2012_01.csv
# 2025-03-02 18:50:10,521 [INFO] Added 'ano' and 'mes' to: VRA_2011_02.csv
# 2025-03-02 18:50:10,548 [INFO] Added 'ano' and 'mes' to: VRA_2002_01.csv
# 2025-03-02 18:50:10,572 [INFO] Added 'ano' and 'mes' to: VRA_2009_08.csv
# 2025-03-02 18:50:10,590 [INFO] Added 'ano' and 'mes' to: VRA_2005_03.csv
# 2025-03-02 18:50:10,643 [INFO] Added 'ano' and 'mes' to: VRA_2018_03.csv
# 2025-03-02 18:50:10,668 [INFO] Added 'ano' and 'mes' to: VRA_2003_04.csv
# 2025-03-02 18:50:10,689 [INFO] Added 'ano' and 'mes' to: VRA_2002_09.csv
# 2025-03-02 18:50:10,747 [INFO] Added 'ano' and 'mes' to: VRA_2024_12.csv
# 2025-03-02 18:50:10,841 [INFO] Added 'ano' and 'mes' to: VRA_2016_08.csv
# 2025-03-02 18:50:10,896 [INFO] Added 'ano' and 'mes' to: VRA_2023_04.csv
# 2025-03-02 18:50:10,953 [INFO] Added 'ano' and 'mes' to: VRA_2018_05.csv
# 2025-03-02 18:50:11,014 [INFO] Added 'ano' and 'mes' to: VRA_2024_01.csv
# 2025-03-02 18:50:11,078 [INFO] Added 'ano' and 'mes' to: VRA_2019_03.csv
# 2025-03-02 18:50:11,102 [INFO] Added 'ano' and 'mes' to: VRA_2000_04.csv
# 2025-03-02 18:50:11,123 [INFO] Added 'ano' and 'mes' to: VRA_2002_11.csv
# 2025-03-02 18:50:11,205 [INFO] Added 'ano' and 'mes' to: VRA_2016_06.csv
# 2025-03-02 18:50:11,232 [INFO] Added 'ano' and 'mes' to: VRA_2020_08.csv
# 2025-03-02 18:50:11,256 [INFO] Added 'ano' and 'mes' to: VRA_2007_07.csv
# 2025-03-02 18:50:11,338 [INFO] Added 'ano' and 'mes' to: VRA_2016_05.csv
# 2025-03-02 18:50:11,370 [INFO] Added 'ano' and 'mes' to: VRA_2020_10.csv
# 2025-03-02 18:50:11,452 [INFO] Added 'ano' and 'mes' to: VRA_2024_11.csv
# 2025-03-02 18:50:11,475 [INFO] Added 'ano' and 'mes' to: VRA_2001_06.csv
# 2025-03-02 18:50:11,574 [INFO] Added 'ano' and 'mes' to: VRA_2011_11.csv
# 2025-03-02 18:50:11,678 [INFO] Added 'ano' and 'mes' to: VRA_2012_05.csv
# 2025-03-02 18:50:11,779 [INFO] Added 'ano' and 'mes' to: VRA_2012_07.csv
# 2025-03-02 18:50:11,802 [INFO] Added 'ano' and 'mes' to: VRA_2000_10.csv
# 2025-03-02 18:50:11,895 [INFO] Added 'ano' and 'mes' to: VRA_2016_01.csv
# 2025-03-02 18:50:11,989 [INFO] Added 'ano' and 'mes' to: VRA_2013_11.csv
# 2025-03-02 18:50:12,048 [INFO] Added 'ano' and 'mes' to: VRA_2024_03.csv
# 2025-03-02 18:50:12,137 [INFO] Added 'ano' and 'mes' to: VRA_2010_11.csv
# 2025-03-02 18:50:12,160 [INFO] Added 'ano' and 'mes' to: VRA_2008_03.csv
# 2025-03-02 18:50:12,209 [INFO] Added 'ano' and 'mes' to: VRA_2022_08.csv
# 2025-03-02 18:50:12,231 [INFO] Added 'ano' and 'mes' to: VRA_2021_04.csv
# 2025-03-02 18:50:12,250 [INFO] Added 'ano' and 'mes' to: VRA_2003_12.csv
# 2025-03-02 18:50:12,346 [INFO] Added 'ano' and 'mes' to: VRA_2013_06.csv
# 2025-03-02 18:50:12,370 [INFO] Added 'ano' and 'mes' to: VRA_2001_01.csv
# 2025-03-02 18:50:12,443 [INFO] Added 'ano' and 'mes' to: VRA_2020_01.csv
# 2025-03-02 18:50:12,468 [INFO] Added 'ano' and 'mes' to: VRA_2002_06.csv
# 2025-03-02 18:50:12,490 [INFO] Added 'ano' and 'mes' to: VRA_2000_12.csv
# 2025-03-02 18:50:12,583 [INFO] Added 'ano' and 'mes' to: VRA_2015_02.csv
# 2025-03-02 18:50:12,603 [INFO] Added 'ano' and 'mes' to: VRA_2003_11.csv
# 2025-03-02 18:50:12,658 [INFO] Added 'ano' and 'mes' to: VRA_2021_12.csv
# 2025-03-02 18:50:12,696 [INFO] Added 'ano' and 'mes' to: VRA_2021_01.csv
# 2025-03-02 18:50:12,717 [INFO] Added 'ano' and 'mes' to: VRA_2005_09.csv
# 2025-03-02 18:50:12,770 [INFO] Added 'ano' and 'mes' to: VRA_2019_02.csv
# 2025-03-02 18:50:12,791 [INFO] Added 'ano' and 'mes' to: VRA_2004_01.csv
# 2025-03-02 18:50:12,814 [INFO] Added 'ano' and 'mes' to: VRA_2009_05.csv
# 2025-03-02 18:50:12,844 [INFO] Added 'ano' and 'mes' to: VRA_2021_03.csv
# 2025-03-02 18:50:12,865 [INFO] Added 'ano' and 'mes' to: VRA_2005_05.csv
# 2025-03-02 18:50:12,888 [INFO] Added 'ano' and 'mes' to: VRA_2002_05.csv
# 2025-03-02 18:50:12,941 [INFO] Added 'ano' and 'mes' to: VRA_2022_11.csv
# 2025-03-02 18:50:12,963 [INFO] Added 'ano' and 'mes' to: VRA_2008_08.csv
# 2025-03-02 18:50:13,054 [INFO] Added 'ano' and 'mes' to: VRA_2011_05.csv
# 2025-03-02 18:50:13,093 [INFO] Added 'ano' and 'mes' to: VRA_2021_07.csv
# 2025-03-02 18:50:13,116 [INFO] Added 'ano' and 'mes' to: VRA_2008_12.csv
# 2025-03-02 18:50:13,136 [INFO] Added 'ano' and 'mes' to: VRA_2001_02.csv
# 2025-03-02 18:50:13,156 [INFO] Added 'ano' and 'mes' to: VRA_2000_06.csv
# 2025-03-02 18:50:13,174 [INFO] Added 'ano' and 'mes' to: VRA_2003_06.csv
# 2025-03-02 18:50:13,196 [INFO] Added 'ano' and 'mes' to: VRA_2009_02.csv
# 2025-03-02 18:50:13,218 [INFO] Added 'ano' and 'mes' to: VRA_2000_03.csv
# 2025-03-02 18:50:13,241 [INFO] Added 'ano' and 'mes' to: VRA_2008_04.csv
# 2025-03-02 18:50:13,255 [INFO] Added 'ano' and 'mes' to: VRA_2020_06.csv
# 2025-03-02 18:50:13,348 [INFO] Added 'ano' and 'mes' to: VRA_2012_09.csv
# 2025-03-02 18:50:13,371 [INFO] Added 'ano' and 'mes' to: VRA_2006_01.csv
# 2025-03-02 18:50:13,470 [INFO] Added 'ano' and 'mes' to: VRA_2013_03.csv
# 2025-03-02 18:50:13,496 [INFO] Added 'ano' and 'mes' to: VRA_2007_01.csv
# 2025-03-02 18:50:13,518 [INFO] Added 'ano' and 'mes' to: VRA_2006_07.csv
# 2025-03-02 18:50:13,573 [INFO] Added 'ano' and 'mes' to: VRA_2024_02.csv
# 2025-03-02 18:50:13,626 [INFO] Added 'ano' and 'mes' to: VRA_2019_11.csv
# 2025-03-02 18:50:13,725 [INFO] Added 'ano' and 'mes' to: VRA_2014_08.csv
# 2025-03-02 18:50:13,745 [INFO] Added 'ano' and 'mes' to: VRA_2020_07.csv
# 2025-03-02 18:50:13,795 [INFO] Added 'ano' and 'mes' to: VRA_2022_01.csv
# 2025-03-02 18:50:13,898 [INFO] Added 'ano' and 'mes' to: VRA_2011_12.csv
# 2025-03-02 18:50:13,902 [INFO] Added 'ano' and 'mes' to: VRA_2014_06.csv
# 2025-03-02 18:50:13,991 [INFO] Added 'ano' and 'mes' to: VRA_2014_11.csv
# 2025-03-02 18:50:14,016 [INFO] Added 'ano' and 'mes' to: VRA_2001_04.csv
# 2025-03-02 18:50:14,094 [INFO] Added 'ano' and 'mes' to: VRA_2017_05.csv
# 2025-03-02 18:50:14,193 [INFO] Added 'ano' and 'mes' to: VRA_2012_04.csv
# 2025-03-02 18:50:14,272 [INFO] Added 'ano' and 'mes' to: VRA_2016_11.csv
# 2025-03-02 18:50:14,297 [INFO] Added 'ano' and 'mes' to: VRA_2007_06.csv
# 2025-03-02 18:50:14,350 [INFO] Added 'ano' and 'mes' to: VRA_2023_09.csv
# 2025-03-02 18:50:14,398 [INFO] Added 'ano' and 'mes' to: VRA_2022_03.csv
# 2025-03-02 18:50:14,486 [INFO] Added 'ano' and 'mes' to: VRA_2010_07.csv
# 2025-03-02 18:50:14,512 [INFO] Added 'ano' and 'mes' to: VRA_2001_07.csv
# 2025-03-02 18:50:14,577 [INFO] Added 'ano' and 'mes' to: VRA_2022_09.csv
# 2025-03-02 18:50:14,654 [INFO] Added 'ano' and 'mes' to: VRA_2017_02.csv
# 2025-03-02 18:50:14,709 [INFO] Added 'ano' and 'mes' to: VRA_2022_10.csv
# 2025-03-02 18:50:14,803 [INFO] Added 'ano' and 'mes' to: VRA_2010_05.csv
# 2025-03-02 18:50:14,827 [INFO] Added 'ano' and 'mes' to: VRA_2009_07.csv
# 2025-03-02 18:50:14,850 [INFO] Added 'ano' and 'mes' to: VRA_2008_11.csv
# 2025-03-02 18:50:14,873 [INFO] Added 'ano' and 'mes' to: VRA_2007_03.csv
# 2025-03-02 18:50:14,970 [INFO] Added 'ano' and 'mes' to: VRA_2015_09.csv
# 2025-03-02 18:50:14,993 [INFO] Added 'ano' and 'mes' to: VRA_2004_10.csv
# 2025-03-02 18:50:15,080 [INFO] Added 'ano' and 'mes' to: VRA_2010_08.csv
# 2025-03-02 18:50:15,139 [INFO] Added 'ano' and 'mes' to: VRA_2024_08.csv
# 2025-03-02 18:50:15,164 [INFO] Added 'ano' and 'mes' to: VRA_2002_10.csv
# 2025-03-02 18:50:15,212 [INFO] Added 'ano' and 'mes' to: VRA_2022_05.csv
# 2025-03-02 18:50:15,304 [INFO] Added 'ano' and 'mes' to: VRA_2011_06.csv
# 2025-03-02 18:50:15,328 [INFO] Added 'ano' and 'mes' to: VRA_2000_11.csv
# 2025-03-02 18:50:15,416 [INFO] Added 'ano' and 'mes' to: VRA_2016_07.csv
# 2025-03-02 18:50:15,440 [INFO] Added 'ano' and 'mes' to: VRA_2002_08.csv
# 2025-03-02 18:50:15,547 [INFO] Added 'ano' and 'mes' to: VRA_2015_06.csv
# 2025-03-02 18:50:15,606 [INFO] Added 'ano' and 'mes' to: VRA_2023_08.csv
# 2025-03-02 18:50:15,635 [INFO] Added 'ano' and 'mes' to: VRA_2009_12.csv
# 2025-03-02 18:50:15,691 [INFO] Added 'ano' and 'mes' to: VRA_2022_12.csv
# 2025-03-02 18:50:15,715 [INFO] Added 'ano' and 'mes' to: VRA_2003_03.csv
# 2025-03-02 18:50:15,808 [INFO] Added 'ano' and 'mes' to: VRA_2011_01.csv
# 2025-03-02 18:50:15,865 [INFO] Added 'ano' and 'mes' to: VRA_2019_04.csv
# 2025-03-02 18:50:15,961 [INFO] Added 'ano' and 'mes' to: VRA_2010_10.csv
# 2025-03-02 18:50:15,993 [INFO] Added 'ano' and 'mes' to: VRA_2021_06.csv
# 2025-03-02 18:50:16,017 [INFO] Added 'ano' and 'mes' to: VRA_2009_06.csv
# 2025-03-02 18:50:16,037 [INFO] Added 'ano' and 'mes' to: VRA_2000_09.csv
# 2025-03-02 18:50:16,040 [INFO] Added 'ano' and 'mes' to: VRA_2014_07.csv
# 2025-03-02 18:50:16,132 [INFO] Added 'ano' and 'mes' to: VRA_2011_10.csv
# 2025-03-02 18:50:16,205 [INFO] Added 'ano' and 'mes' to: VRA_2023_11.csv
# 2025-03-02 18:50:16,227 [INFO] Added 'ano' and 'mes' to: VRA_2001_10.csv
# 2025-03-02 18:50:16,285 [INFO] Added 'ano' and 'mes' to: VRA_2019_10.csv
# 2025-03-02 18:50:16,308 [INFO] Added 'ano' and 'mes' to: VRA_2007_12.csv
# 2025-03-02 18:50:16,329 [INFO] Added 'ano' and 'mes' to: VRA_2005_08.csv
# 2025-03-02 18:50:16,353 [INFO] Added 'ano' and 'mes' to: VRA_2020_09.csv
# 2025-03-02 18:50:16,371 [INFO] Added 'ano' and 'mes' to: VRA_2004_09.csv
# 2025-03-02 18:50:16,392 [INFO] Added 'ano' and 'mes' to: VRA_2008_05.csv
# 2025-03-02 18:50:16,404 [INFO] Added 'ano' and 'mes' to: VRA_2020_05.csv
# 2025-03-02 18:50:16,512 [INFO] Added 'ano' and 'mes' to: VRA_2014_12.csv
# 2025-03-02 18:50:16,575 [INFO] Added 'ano' and 'mes' to: VRA_2019_07.csv
# 2025-03-02 18:50:16,603 [INFO] Added 'ano' and 'mes' to: VRA_2009_10.csv
# 2025-03-02 18:50:16,682 [INFO] Added 'ano' and 'mes' to: VRA_2017_08.csv
# 2025-03-02 18:50:16,706 [INFO] Added 'ano' and 'mes' to: VRA_2000_02.csv
# 2025-03-02 18:50:16,736 [INFO] Added 'ano' and 'mes' to: VRA_2006_08.csv
# 2025-03-02 18:50:16,836 [INFO] Added 'ano' and 'mes' to: VRA_2015_10.csv
# 2025-03-02 18:50:16,928 [INFO] Added 'ano' and 'mes' to: VRA_2019_06.csv
# 2025-03-02 18:50:16,948 [INFO] Added 'ano' and 'mes' to: VRA_2003_10.csv
# 2025-03-02 18:50:16,970 [INFO] Added 'ano' and 'mes' to: VRA_2005_01.csv
# 2025-03-02 18:50:17,001 [INFO] Added 'ano' and 'mes' to: VRA_2021_02.csv
# 2025-03-02 18:50:17,019 [INFO] Added 'ano' and 'mes' to: VRA_2003_08.csv
# 2025-03-02 18:50:17,115 [INFO] Added 'ano' and 'mes' to: VRA_2013_05.csv
# 2025-03-02 18:50:17,140 [INFO] Added 'ano' and 'mes' to: VRA_2001_03.csv
# 2025-03-02 18:50:17,192 [INFO] Added 'ano' and 'mes' to: VRA_2023_05.csv
# 2025-03-02 18:50:17,239 [INFO] Added 'ano' and 'mes' to: VRA_2021_11.csv
# 2025-03-02 18:50:17,259 [INFO] Added 'ano' and 'mes' to: VRA_2008_02.csv
# 2025-03-02 18:50:17,281 [INFO] Added 'ano' and 'mes' to: VRA_2000_08.csv
# 2025-03-02 18:50:17,303 [INFO] Added 'ano' and 'mes' to: VRA_2003_05.csv
# 2025-03-02 18:50:17,364 [INFO] Added 'ano' and 'mes' to: VRA_2018_08.csv
# 2025-03-02 18:50:17,456 [INFO] Added 'ano' and 'mes' to: VRA_2018_01.csv
# 2025-03-02 18:50:17,538 [INFO] Added 'ano' and 'mes' to: VRA_2023_12.csv
# 2025-03-02 18:50:17,579 [INFO] Added 'ano' and 'mes' to: VRA_2021_08.csv
# 2025-03-02 18:50:17,602 [INFO] Added 'ano' and 'mes' to: VRA_2009_04.csv
# 2025-03-02 18:50:17,699 [INFO] Added 'ano' and 'mes' to: VRA_2015_08.csv
# 2025-03-02 18:50:17,723 [INFO] Added 'ano' and 'mes' to: VRA_2000_07.csv
# 2025-03-02 18:50:17,745 [INFO] Added 'ano' and 'mes' to: VRA_2007_05.csv
# 2025-03-02 18:50:17,847 [INFO] Added 'ano' and 'mes' to: VRA_2012_06.csv
# 2025-03-02 18:50:17,954 [INFO] Added 'ano' and 'mes' to: VRA_2011_07.csv
# 2025-03-02 18:50:18,052 [INFO] Added 'ano' and 'mes' to: VRA_2014_02.csv
# 2025-03-02 18:50:18,080 [INFO] Added 'ano' and 'mes' to: VRA_2002_12.csv
# 2025-03-02 18:50:18,122 [INFO] Added 'ano' and 'mes' to: VRA_2021_09.csv
# 2025-03-02 18:50:18,156 [INFO] Added 'ano' and 'mes' to: VRA_2021_05.csv
# 2025-03-02 18:50:18,180 [INFO] Added 'ano' and 'mes' to: VRA_2006_12.csv
# 2025-03-02 18:50:18,279 [INFO] Added 'ano' and 'mes' to: VRA_2015_05.csv
# 2025-03-02 18:50:18,375 [INFO] Added 'ano' and 'mes' to: VRA_2016_03.csv
# 2025-03-02 18:50:18,450 [INFO] Added 'ano' and 'mes' to: VRA_2018_07.csv
# 2025-03-02 18:50:18,555 [INFO] Added 'ano' and 'mes' to: VRA_2013_12.csv
# 2025-03-02 18:50:18,580 [INFO] Added 'ano' and 'mes' to: VRA_2007_09.csv
# 2025-03-02 18:50:18,602 [INFO] Added 'ano' and 'mes' to: VRA_2009_03.csv
# 2025-03-02 18:50:18,680 [INFO] Added 'ano' and 'mes' to: VRA_2016_09.csv
# 2025-03-02 18:50:18,742 [INFO] Added 'ano' and 'mes' to: VRA_2019_08.csv
# 2025-03-02 18:50:18,764 [INFO] Added 'ano' and 'mes' to: VRA_2005_11.csv
# 2025-03-02 18:50:18,855 [INFO] Added 'ano' and 'mes' to: VRA_2013_09.csv
# 2025-03-02 18:50:18,958 [INFO] Added 'ano' and 'mes' to: VRA_2014_01.csv
# 2025-03-02 18:50:18,981 [INFO] Added 'ano' and 'mes' to: VRA_2006_09.csv
# 2025-03-02 18:50:19,079 [INFO] Added 'ano' and 'mes' to: VRA_2010_12.csv
# 2025-03-02 18:50:19,103 [INFO] Added 'ano' and 'mes' to: VRA_2008_01.csv
# 2025-03-02 18:50:19,124 [INFO] Added 'ano' and 'mes' to: VRA_2000_05.csv
# 2025-03-02 18:50:19,144 [INFO] Added 'ano' and 'mes' to: VRA_2001_11.csv
# 2025-03-02 18:50:19,165 [INFO] Added 'ano' and 'mes' to: VRA_2001_09.csv
# 2025-03-02 18:50:19,243 [INFO] Added 'ano' and 'mes' to: VRA_2024_09.csv
# 2025-03-02 18:50:19,264 [INFO] Added 'ano' and 'mes' to: VRA_2004_02.csv
# 2025-03-02 18:50:19,360 [INFO] Added 'ano' and 'mes' to: VRA_2015_12.csv
# 2025-03-02 18:50:19,447 [INFO] Added 'ano' and 'mes' to: VRA_2024_10.csv
# 2025-03-02 18:50:19,509 [INFO] Added 'ano' and 'mes' to: VRA_2023_07.csv
# 2025-03-02 18:50:19,601 [INFO] Added 'ano' and 'mes' to: VRA_2013_02.csv
# 2025-03-02 18:50:19,662 [INFO] Added 'ano' and 'mes' to: VRA_2018_10.csv
# 2025-03-02 18:50:19,723 [INFO] Added 'ano' and 'mes' to: VRA_2023_01.csv
# 2025-03-02 18:50:19,821 [INFO] Added 'ano' and 'mes' to: VRA_2011_09.csv
# 2025-03-02 18:50:19,846 [INFO] Added 'ano' and 'mes' to: VRA_2007_04.csv
# 2025-03-02 18:50:19,869 [INFO] Added 'ano' and 'mes' to: VRA_2001_05.csv
# 2025-03-02 18:50:19,929 [INFO] Added 'ano' and 'mes' to: VRA_2025_01.csv
# 2025-03-02 18:50:19,940 [INFO] Added 'ano' and 'mes' to: VRA_2020_04.csv
# 2025-03-02 18:50:20,042 [INFO] Added 'ano' and 'mes' to: VRA_2013_01.csv
# 2025-03-02 18:50:20,068 [INFO] Added 'ano' and 'mes' to: VRA_2003_02.csv
# 2025-03-02 18:50:20,153 [INFO] Added 'ano' and 'mes' to: VRA_2024_07.csv
# 2025-03-02 18:50:20,265 [INFO] Added 'ano' and 'mes' to: VRA_2015_01.csv
# 2025-03-02 18:50:20,365 [INFO] Added 'ano' and 'mes' to: VRA_2013_08.csv
# 2025-03-02 18:50:20,418 [INFO] Added 'ano' and 'mes' to: VRA_2024_06.csv
# 2025-03-02 18:50:20,497 [INFO] Added 'ano' and 'mes' to: VRA_2017_06.csv
# 2025-03-02 18:50:20,597 [INFO] Added 'ano' and 'mes' to: VRA_2016_02.csv
# 2025-03-02 18:50:20,656 [INFO] Added 'ano' and 'mes' to: VRA_2019_09.csv
# 2025-03-02 18:50:20,679 [INFO] Added 'ano' and 'mes' to: VRA_2005_10.csv
# 2025-03-02 18:50:20,781 [INFO] Added 'ano' and 'mes' to: VRA_2015_03.csv
# 2025-03-02 18:50:20,838 [INFO] Added 'ano' and 'mes' to: VRA_2018_11.csv
# 2025-03-02 18:50:20,860 [INFO] Added 'ano' and 'mes' to: VRA_2002_07.csv
# 2025-03-02 18:50:20,909 [INFO] Added 'ano' and 'mes' to: VRA_2023_06.csv
# 2025-03-02 18:50:20,961 [INFO] Added 'ano' and 'mes' to: VRA_2018_06.csv
# 2025-03-02 18:50:20,982 [INFO] Added 'ano' and 'mes' to: VRA_2006_04.csv
# 2025-03-02 18:50:21,077 [INFO] Added 'ano' and 'mes' to: VRA_2012_02.csv
# 2025-03-02 18:50:21,174 [INFO] Added 'ano' and 'mes' to: VRA_2014_04.csv
# 2025-03-02 18:50:21,195 [INFO] Added 'ano' and 'mes' to: VRA_2005_06.csv
# 2025-03-02 18:50:21,219 [INFO] Added 'ano' and 'mes' to: VRA_2001_08.csv
# 2025-03-02 18:50:21,239 [INFO] Added 'ano' and 'mes' to: VRA_2008_10.csv
# 2025-03-02 18:50:21,332 [INFO] Added 'ano' and 'mes' to: VRA_2016_04.csv
# 2025-03-02 18:50:21,424 [INFO] Added 'ano' and 'mes' to: VRA_2010_09.csv
# 2025-03-02 18:50:21,485 [INFO] Added 'ano' and 'mes' to: VRA_2018_09.csv
# 2025-03-02 18:50:21,510 [INFO] Added 'ano' and 'mes' to: VRA_2009_09.csv
# 2025-03-02 18:50:21,530 [INFO] Added 'ano' and 'mes' to: VRA_2008_07.csv
# 2025-03-02 18:50:21,618 [INFO] Added 'ano' and 'mes' to: VRA_2016_12.csv
# 2025-03-02 18:50:21,718 [INFO] Added 'ano' and 'mes' to: VRA_2015_04.csv
# 2025-03-02 18:50:21,814 [INFO] Added 'ano' and 'mes' to: VRA_2012_11.csv
# 2025-03-02 18:50:21,878 [INFO] Added 'ano' and 'mes' to: VRA_2019_12.csv
# 2025-03-02 18:50:21,911 [INFO] Added 'ano' and 'mes' to: VRA_2000_01.csv
# 2025-03-02 18:50:21,938 [INFO] Added 'ano' and 'mes' to: VRA_2009_11.csv
# 2025-03-02 18:50:22,041 [INFO] Added 'ano' and 'mes' to: VRA_2014_10.csv
# 2025-03-02 18:50:22,064 [INFO] Added 'ano' and 'mes' to: VRA_2008_09.csv
# 2025-03-02 18:50:22,163 [INFO] Added 'ano' and 'mes' to: VRA_2012_10.csv
# 2025-03-02 18:50:22,218 [INFO] Added 'ano' and 'mes' to: VRA_2022_02.csv
# 2025-03-02 18:50:22,240 [INFO] Added 'ano' and 'mes' to: VRA_2006_06.csv
# 2025-03-02 18:50:22,338 [INFO] Added 'ano' and 'mes' to: VRA_2012_12.csv
# 2025-03-02 18:50:22,365 [INFO] Added 'ano' and 'mes' to: VRA_2007_10.csv
# 2025-03-02 18:50:22,384 [INFO] Added 'ano' and 'mes' to: VRA_2004_07.csv
# 2025-03-02 18:50:22,405 [INFO] Added 'ano' and 'mes' to: VRA_2005_07.csv
# 2025-03-02 18:50:22,425 [INFO] Added 'ano' and 'mes' to: VRA_2004_12.csv
# 2025-03-02 18:50:22,447 [INFO] Added 'ano' and 'mes' to: VRA_2007_08.csv
# 2025-03-02 18:50:22,492 [INFO] Added 'ano' and 'mes' to: VRA_2022_06.csv
# 2025-03-02 18:50:22,586 [INFO] Added 'ano' and 'mes' to: VRA_2010_01.csv
# 2025-03-02 18:50:22,609 [INFO] Added 'ano' and 'mes' to: VRA_2002_04.csv
# 2025-03-02 18:50:22,628 [INFO] Added 'ano' and 'mes' to: VRA_2004_06.csv
# 2025-03-02 18:50:22,647 [INFO] Added 'ano' and 'mes' to: VRA_2004_03.csv
# 2025-03-02 18:50:22,650 [INFO] Adding 'ano' and 'mes' columns completed.

# %% [markdown]
# # Overview
#
# This script forces all values in CSV files located in the "helium" folder to be strings. It reads each CSV with Polars, converts every column to string type, and then overwrites the original file. All actions are logged in "csv_force_string.log" for accountability.
#
# ## What it does
#
# - **Logging configuration:**
#   Sets up logging to record every action and error in "csv_force_string.log" with clear timestamps and log levels. Nothing escapes the log.
#
# - **File iteration:**
#   Scans the "helium" folder for CSV files. It processes only those files that end with ".csv" and ensures they're actual files, not directories.
#
# - **CSV conversion:**
#   For each CSV file:
#   - Reads the file using Polars, initially treating all columns as strings.
#   - Explicitly converts every column to string type.
#   - Overwrites the original file with the new, string-only version using semicolon delimiters.
#
# - **Error handling:**
#   Logs successful conversions and any errors encountered during processing, ensuring you’re fully informed of every move.
#
# ## Why it does it
#
# Because ambiguity in data types is unacceptable. This script enforces strict consistency by converting every CSV value to a string, preemptively eliminating type-related issues in your data processing pipeline.

# %%
# Configure logging
log_file = "csv_force_string.log"
logging.basicConfig(
    filename=log_file,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# Folder containing the files
input_folder = "helium"

def convert_all_to_string():
    for file_name in os.listdir(input_folder):
        file_path = os.path.join(input_folder, file_name)

        if file_name.endswith(".csv") and os.path.isfile(file_path):
            try:
                # Read CSV assuming all columns as string
                df = pl.read_csv(file_path, separator=";", encoding="utf-8", infer_schema_length=0, dtypes={})

                # Convert all columns to string
                df = df.with_columns([df[col].cast(pl.Utf8) for col in df.columns])

                # Overwrite the original file
                df.write_csv(file_path, separator=";", include_header=True)

                logging.info(f"Converted all values to string in: {file_name}")

            except Exception as e:
                logging.error(f"Error processing {file_name}: {e}")

# %%
logging.info("Forcing all values to string started.")
convert_all_to_string()
logging.info("Forcing all values to string completed.")
# Out:
# 2025-03-02 18:51:53,728 [INFO] Forcing all values to string started.
# /tmp/ipykernel_3968/3402976836.py:20: DeprecationWarning: The argument `dtypes` for `read_csv` is deprecated. It has been renamed to `schema_overrides`.
#   df = pl.read_csv(file_path, separator=";", encoding="utf-8", infer_schema_length=0, dtypes={})
# 2025-03-02 18:51:53,748 [INFO] Converted all values to string in: VRA_2002_02.csv
# 2025-03-02 18:51:53,768 [INFO] Converted all values to string in: VRA_2006_03.csv
# 2025-03-02 18:51:53,791 [INFO] Converted all values to string in: VRA_2001_12.csv
# 2025-03-02 18:51:53,841 [INFO] Converted all values to string in: VRA_2023_02.csv
# 2025-03-02 18:51:53,858 [INFO] Converted all values to string in: VRA_2004_11.csv
# 2025-03-02 18:51:53,879 [INFO] Converted all values to string in: VRA_2008_06.csv
# 2025-03-02 18:51:53,898 [INFO] Converted all values to string in: VRA_2004_05.csv
# 2025-03-02 18:51:53,990 [INFO] Converted all values to string in: VRA_2010_06.csv
# 2025-03-02 18:51:54,046 [INFO] Converted all values to string in: VRA_2024_04.csv
# 2025-03-02 18:51:54,143 [INFO] Converted all values to string in: VRA_2014_09.csv
# 2025-03-02 18:51:54,166 [INFO] Converted all values to string in: VRA_2006_05.csv
# 2025-03-02 18:51:54,249 [INFO] Converted all values to string in: VRA_2016_10.csv
# 2025-03-02 18:51:54,269 [INFO] Converted all values to string in: VRA_2007_02.csv
# 2025-03-02 18:51:54,313 [INFO] Converted all values to string in: VRA_2022_04.csv
# 2025-03-02 18:51:54,331 [INFO] Converted all values to string in: VRA_2006_11.csv
# 2025-03-02 18:51:54,389 [INFO] Converted all values to string in: VRA_2020_02.csv
# 2025-03-02 18:51:54,412 [INFO] Converted all values to string in: VRA_2009_01.csv
# 2025-03-02 18:51:54,485 [INFO] Converted all values to string in: VRA_2010_02.csv
# 2025-03-02 18:51:54,581 [INFO] Converted all values to string in: VRA_2014_05.csv
# 2025-03-02 18:51:54,602 [INFO] Converted all values to string in: VRA_2006_02.csv
# 2025-03-02 18:51:54,618 [INFO] Converted all values to string in: VRA_2005_04.csv
# 2025-03-02 18:51:54,700 [INFO] Converted all values to string in: VRA_2017_10.csv
# 2025-03-02 18:51:54,732 [INFO] Converted all values to string in: VRA_2020_11.csv
# 2025-03-02 18:51:54,808 [INFO] Converted all values to string in: VRA_2018_02.csv
# 2025-03-02 18:51:54,905 [INFO] Converted all values to string in: VRA_2014_03.csv
# 2025-03-02 18:51:54,983 [INFO] Converted all values to string in: VRA_2017_09.csv
# 2025-03-02 18:51:55,002 [INFO] Converted all values to string in: VRA_2003_09.csv
# 2025-03-02 18:51:55,054 [INFO] Converted all values to string in: VRA_2021_10.csv
# 2025-03-02 18:51:55,139 [INFO] Converted all values to string in: VRA_2017_12.csv
# 2025-03-02 18:51:55,211 [INFO] Converted all values to string in: VRA_2018_12.csv
# 2025-03-02 18:51:55,310 [INFO] Converted all values to string in: VRA_2011_03.csv
# 2025-03-02 18:51:55,401 [INFO] Converted all values to string in: VRA_2013_04.csv
# 2025-03-02 18:51:55,501 [INFO] Converted all values to string in: VRA_2013_07.csv
# 2025-03-02 18:51:55,580 [INFO] Converted all values to string in: VRA_2017_11.csv
# 2025-03-02 18:51:55,633 [INFO] Converted all values to string in: VRA_2019_05.csv
# 2025-03-02 18:51:55,731 [INFO] Converted all values to string in: VRA_2011_04.csv
# 2025-03-02 18:51:55,836 [INFO] Converted all values to string in: VRA_2012_03.csv
# 2025-03-02 18:51:55,934 [INFO] Converted all values to string in: VRA_2013_10.csv
# 2025-03-02 18:51:56,026 [INFO] Converted all values to string in: VRA_2015_11.csv
# 2025-03-02 18:51:56,128 [INFO] Converted all values to string in: VRA_2011_08.csv
# 2025-03-02 18:51:56,203 [INFO] Converted all values to string in: VRA_2019_01.csv
# 2025-03-02 18:51:56,260 [INFO] Converted all values to string in: VRA_2023_10.csv
# 2025-03-02 18:51:56,367 [INFO] Converted all values to string in: VRA_2015_07.csv
# 2025-03-02 18:51:56,389 [INFO] Converted all values to string in: VRA_2003_07.csv
# 2025-03-02 18:51:56,405 [INFO] Converted all values to string in: VRA_2005_02.csv
# 2025-03-02 18:51:56,484 [INFO] Converted all values to string in: VRA_2017_04.csv
# 2025-03-02 18:51:56,534 [INFO] Converted all values to string in: VRA_2022_07.csv
# 2025-03-02 18:51:56,557 [INFO] Converted all values to string in: VRA_2004_08.csv
# 2025-03-02 18:51:56,643 [INFO] Converted all values to string in: VRA_2017_07.csv
# 2025-03-02 18:51:56,662 [INFO] Converted all values to string in: VRA_2004_04.csv
# 2025-03-02 18:51:56,700 [INFO] Converted all values to string in: VRA_2020_12.csv
# 2025-03-02 18:51:56,720 [INFO] Converted all values to string in: VRA_2007_11.csv
# 2025-03-02 18:51:56,761 [INFO] Converted all values to string in: VRA_2020_03.csv
# 2025-03-02 18:51:56,780 [INFO] Converted all values to string in: VRA_2005_12.csv
# 2025-03-02 18:51:56,800 [INFO] Converted all values to string in: VRA_2003_01.csv
# 2025-03-02 18:51:56,819 [INFO] Converted all values to string in: VRA_2002_03.csv
# 2025-03-02 18:51:56,869 [INFO] Converted all values to string in: VRA_2024_05.csv
# 2025-03-02 18:51:56,950 [INFO] Converted all values to string in: VRA_2017_03.csv
# 2025-03-02 18:51:56,971 [INFO] Converted all values to string in: VRA_2006_10.csv
# 2025-03-02 18:51:57,058 [INFO] Converted all values to string in: VRA_2010_03.csv
# 2025-03-02 18:51:57,116 [INFO] Converted all values to string in: VRA_2018_04.csv
# 2025-03-02 18:51:57,220 [INFO] Converted all values to string in: VRA_2012_08.csv
# 2025-03-02 18:51:57,310 [INFO] Converted all values to string in: VRA_2017_01.csv
# 2025-03-02 18:51:57,365 [INFO] Converted all values to string in: VRA_2023_03.csv
# 2025-03-02 18:51:57,453 [INFO] Converted all values to string in: VRA_2010_04.csv
# 2025-03-02 18:51:57,559 [INFO] Converted all values to string in: VRA_2012_01.csv
# 2025-03-02 18:51:57,647 [INFO] Converted all values to string in: VRA_2011_02.csv
# 2025-03-02 18:51:57,671 [INFO] Converted all values to string in: VRA_2002_01.csv
# 2025-03-02 18:51:57,692 [INFO] Converted all values to string in: VRA_2009_08.csv
# 2025-03-02 18:51:57,710 [INFO] Converted all values to string in: VRA_2005_03.csv
# 2025-03-02 18:51:57,760 [INFO] Converted all values to string in: VRA_2018_03.csv
# 2025-03-02 18:51:57,780 [INFO] Converted all values to string in: VRA_2003_04.csv
# 2025-03-02 18:51:57,800 [INFO] Converted all values to string in: VRA_2002_09.csv
# 2025-03-02 18:51:57,857 [INFO] Converted all values to string in: VRA_2024_12.csv
# 2025-03-02 18:51:57,944 [INFO] Converted all values to string in: VRA_2016_08.csv
# 2025-03-02 18:51:57,996 [INFO] Converted all values to string in: VRA_2023_04.csv
# 2025-03-02 18:51:58,054 [INFO] Converted all values to string in: VRA_2018_05.csv
# 2025-03-02 18:51:58,112 [INFO] Converted all values to string in: VRA_2024_01.csv
# 2025-03-02 18:51:58,172 [INFO] Converted all values to string in: VRA_2019_03.csv
# 2025-03-02 18:51:58,194 [INFO] Converted all values to string in: VRA_2000_04.csv
# 2025-03-02 18:51:58,213 [INFO] Converted all values to string in: VRA_2002_11.csv
# 2025-03-02 18:51:58,292 [INFO] Converted all values to string in: VRA_2016_06.csv
# 2025-03-02 18:51:58,317 [INFO] Converted all values to string in: VRA_2020_08.csv
# 2025-03-02 18:51:58,341 [INFO] Converted all values to string in: VRA_2007_07.csv
# 2025-03-02 18:51:58,427 [INFO] Converted all values to string in: VRA_2016_05.csv
# 2025-03-02 18:51:58,457 [INFO] Converted all values to string in: VRA_2020_10.csv
# 2025-03-02 18:51:58,538 [INFO] Converted all values to string in: VRA_2024_11.csv
# 2025-03-02 18:51:58,561 [INFO] Converted all values to string in: VRA_2001_06.csv
# 2025-03-02 18:51:58,664 [INFO] Converted all values to string in: VRA_2011_11.csv
# 2025-03-02 18:51:58,767 [INFO] Converted all values to string in: VRA_2012_05.csv
# 2025-03-02 18:51:58,872 [INFO] Converted all values to string in: VRA_2012_07.csv
# 2025-03-02 18:51:58,895 [INFO] Converted all values to string in: VRA_2000_10.csv
# 2025-03-02 18:51:58,991 [INFO] Converted all values to string in: VRA_2016_01.csv
# 2025-03-02 18:51:59,084 [INFO] Converted all values to string in: VRA_2013_11.csv
# 2025-03-02 18:51:59,140 [INFO] Converted all values to string in: VRA_2024_03.csv
# 2025-03-02 18:51:59,232 [INFO] Converted all values to string in: VRA_2010_11.csv
# 2025-03-02 18:51:59,256 [INFO] Converted all values to string in: VRA_2008_03.csv
# 2025-03-02 18:51:59,304 [INFO] Converted all values to string in: VRA_2022_08.csv
# 2025-03-02 18:51:59,326 [INFO] Converted all values to string in: VRA_2021_04.csv
# 2025-03-02 18:51:59,344 [INFO] Converted all values to string in: VRA_2003_12.csv
# 2025-03-02 18:51:59,438 [INFO] Converted all values to string in: VRA_2013_06.csv
# 2025-03-02 18:51:59,461 [INFO] Converted all values to string in: VRA_2001_01.csv
# 2025-03-02 18:51:59,522 [INFO] Converted all values to string in: VRA_2020_01.csv
# 2025-03-02 18:51:59,543 [INFO] Converted all values to string in: VRA_2002_06.csv
# 2025-03-02 18:51:59,564 [INFO] Converted all values to string in: VRA_2000_12.csv
# 2025-03-02 18:51:59,658 [INFO] Converted all values to string in: VRA_2015_02.csv
# 2025-03-02 18:51:59,677 [INFO] Converted all values to string in: VRA_2003_11.csv
# 2025-03-02 18:51:59,726 [INFO] Converted all values to string in: VRA_2021_12.csv
# 2025-03-02 18:51:59,765 [INFO] Converted all values to string in: VRA_2021_01.csv
# 2025-03-02 18:51:59,784 [INFO] Converted all values to string in: VRA_2005_09.csv
# 2025-03-02 18:51:59,838 [INFO] Converted all values to string in: VRA_2019_02.csv
# 2025-03-02 18:51:59,866 [INFO] Converted all values to string in: VRA_2004_01.csv
# 2025-03-02 18:51:59,894 [INFO] Converted all values to string in: VRA_2009_05.csv
# 2025-03-02 18:51:59,925 [INFO] Converted all values to string in: VRA_2021_03.csv
# 2025-03-02 18:51:59,946 [INFO] Converted all values to string in: VRA_2005_05.csv
# 2025-03-02 18:51:59,967 [INFO] Converted all values to string in: VRA_2002_05.csv
# 2025-03-02 18:52:00,023 [INFO] Converted all values to string in: VRA_2022_11.csv
# 2025-03-02 18:52:00,045 [INFO] Converted all values to string in: VRA_2008_08.csv
# 2025-03-02 18:52:00,147 [INFO] Converted all values to string in: VRA_2011_05.csv
# 2025-03-02 18:52:00,185 [INFO] Converted all values to string in: VRA_2021_07.csv
# 2025-03-02 18:52:00,206 [INFO] Converted all values to string in: VRA_2008_12.csv
# 2025-03-02 18:52:00,226 [INFO] Converted all values to string in: VRA_2001_02.csv
# 2025-03-02 18:52:00,246 [INFO] Converted all values to string in: VRA_2000_06.csv
# 2025-03-02 18:52:00,264 [INFO] Converted all values to string in: VRA_2003_06.csv
# 2025-03-02 18:52:00,287 [INFO] Converted all values to string in: VRA_2009_02.csv
# 2025-03-02 18:52:00,311 [INFO] Converted all values to string in: VRA_2000_03.csv
# 2025-03-02 18:52:00,331 [INFO] Converted all values to string in: VRA_2008_04.csv
# 2025-03-02 18:52:00,344 [INFO] Converted all values to string in: VRA_2020_06.csv
# 2025-03-02 18:52:00,440 [INFO] Converted all values to string in: VRA_2012_09.csv
# 2025-03-02 18:52:00,462 [INFO] Converted all values to string in: VRA_2006_01.csv
# 2025-03-02 18:52:00,558 [INFO] Converted all values to string in: VRA_2013_03.csv
# 2025-03-02 18:52:00,584 [INFO] Converted all values to string in: VRA_2007_01.csv
# 2025-03-02 18:52:00,604 [INFO] Converted all values to string in: VRA_2006_07.csv
# 2025-03-02 18:52:00,664 [INFO] Converted all values to string in: VRA_2024_02.csv
# 2025-03-02 18:52:00,720 [INFO] Converted all values to string in: VRA_2019_11.csv
# 2025-03-02 18:52:00,820 [INFO] Converted all values to string in: VRA_2014_08.csv
# 2025-03-02 18:52:00,839 [INFO] Converted all values to string in: VRA_2020_07.csv
# 2025-03-02 18:52:00,886 [INFO] Converted all values to string in: VRA_2022_01.csv
# 2025-03-02 18:52:00,990 [INFO] Converted all values to string in: VRA_2011_12.csv
# 2025-03-02 18:52:00,994 [INFO] Converted all values to string in: VRA_2014_06.csv
# 2025-03-02 18:52:01,088 [INFO] Converted all values to string in: VRA_2014_11.csv
# 2025-03-02 18:52:01,110 [INFO] Converted all values to string in: VRA_2001_04.csv
# 2025-03-02 18:52:01,188 [INFO] Converted all values to string in: VRA_2017_05.csv
# 2025-03-02 18:52:01,289 [INFO] Converted all values to string in: VRA_2012_04.csv
# 2025-03-02 18:52:01,375 [INFO] Converted all values to string in: VRA_2016_11.csv
# 2025-03-02 18:52:01,398 [INFO] Converted all values to string in: VRA_2007_06.csv
# 2025-03-02 18:52:01,452 [INFO] Converted all values to string in: VRA_2023_09.csv
# 2025-03-02 18:52:01,496 [INFO] Converted all values to string in: VRA_2022_03.csv
# 2025-03-02 18:52:01,585 [INFO] Converted all values to string in: VRA_2010_07.csv
# 2025-03-02 18:52:01,609 [INFO] Converted all values to string in: VRA_2001_07.csv
# 2025-03-02 18:52:01,671 [INFO] Converted all values to string in: VRA_2022_09.csv
# 2025-03-02 18:52:01,748 [INFO] Converted all values to string in: VRA_2017_02.csv
# 2025-03-02 18:52:01,802 [INFO] Converted all values to string in: VRA_2022_10.csv
# 2025-03-02 18:52:01,889 [INFO] Converted all values to string in: VRA_2010_05.csv
# 2025-03-02 18:52:01,913 [INFO] Converted all values to string in: VRA_2009_07.csv
# 2025-03-02 18:52:01,934 [INFO] Converted all values to string in: VRA_2008_11.csv
# 2025-03-02 18:52:01,956 [INFO] Converted all values to string in: VRA_2007_03.csv
# 2025-03-02 18:52:02,057 [INFO] Converted all values to string in: VRA_2015_09.csv
# 2025-03-02 18:52:02,077 [INFO] Converted all values to string in: VRA_2004_10.csv
# 2025-03-02 18:52:02,165 [INFO] Converted all values to string in: VRA_2010_08.csv
# 2025-03-02 18:52:02,223 [INFO] Converted all values to string in: VRA_2024_08.csv
# 2025-03-02 18:52:02,248 [INFO] Converted all values to string in: VRA_2002_10.csv
# 2025-03-02 18:52:02,296 [INFO] Converted all values to string in: VRA_2022_05.csv
# 2025-03-02 18:52:02,389 [INFO] Converted all values to string in: VRA_2011_06.csv
# 2025-03-02 18:52:02,411 [INFO] Converted all values to string in: VRA_2000_11.csv
# 2025-03-02 18:52:02,491 [INFO] Converted all values to string in: VRA_2016_07.csv
# 2025-03-02 18:52:02,514 [INFO] Converted all values to string in: VRA_2002_08.csv
# 2025-03-02 18:52:02,609 [INFO] Converted all values to string in: VRA_2015_06.csv
# 2025-03-02 18:52:02,672 [INFO] Converted all values to string in: VRA_2023_08.csv
# 2025-03-02 18:52:02,702 [INFO] Converted all values to string in: VRA_2009_12.csv
# 2025-03-02 18:52:02,760 [INFO] Converted all values to string in: VRA_2022_12.csv
# 2025-03-02 18:52:02,784 [INFO] Converted all values to string in: VRA_2003_03.csv
# 2025-03-02 18:52:02,879 [INFO] Converted all values to string in: VRA_2011_01.csv
# 2025-03-02 18:52:02,936 [INFO] Converted all values to string in: VRA_2019_04.csv
# 2025-03-02 18:52:03,029 [INFO] Converted all values to string in: VRA_2010_10.csv
# 2025-03-02 18:52:03,060 [INFO] Converted all values to string in: VRA_2021_06.csv
# 2025-03-02 18:52:03,082 [INFO] Converted all values to string in: VRA_2009_06.csv
# 2025-03-02 18:52:03,103 [INFO] Converted all values to string in: VRA_2000_09.csv
# 2025-03-02 18:52:03,107 [INFO] Converted all values to string in: VRA_2014_07.csv
# 2025-03-02 18:52:03,203 [INFO] Converted all values to string in: VRA_2011_10.csv
# 2025-03-02 18:52:03,284 [INFO] Converted all values to string in: VRA_2023_11.csv
# 2025-03-02 18:52:03,306 [INFO] Converted all values to string in: VRA_2001_10.csv
# 2025-03-02 18:52:03,367 [INFO] Converted all values to string in: VRA_2019_10.csv
# 2025-03-02 18:52:03,391 [INFO] Converted all values to string in: VRA_2007_12.csv
# 2025-03-02 18:52:03,410 [INFO] Converted all values to string in: VRA_2005_08.csv
# 2025-03-02 18:52:03,432 [INFO] Converted all values to string in: VRA_2020_09.csv
# 2025-03-02 18:52:03,449 [INFO] Converted all values to string in: VRA_2004_09.csv
# 2025-03-02 18:52:03,470 [INFO] Converted all values to string in: VRA_2008_05.csv
# 2025-03-02 18:52:03,482 [INFO] Converted all values to string in: VRA_2020_05.csv
# 2025-03-02 18:52:03,594 [INFO] Converted all values to string in: VRA_2014_12.csv
# 2025-03-02 18:52:03,655 [INFO] Converted all values to string in: VRA_2019_07.csv
# 2025-03-02 18:52:03,678 [INFO] Converted all values to string in: VRA_2009_10.csv
# 2025-03-02 18:52:03,758 [INFO] Converted all values to string in: VRA_2017_08.csv
# 2025-03-02 18:52:03,780 [INFO] Converted all values to string in: VRA_2000_02.csv
# 2025-03-02 18:52:03,799 [INFO] Converted all values to string in: VRA_2006_08.csv
# 2025-03-02 18:52:03,891 [INFO] Converted all values to string in: VRA_2015_10.csv
# 2025-03-02 18:52:03,972 [INFO] Converted all values to string in: VRA_2019_06.csv
# 2025-03-02 18:52:03,991 [INFO] Converted all values to string in: VRA_2003_10.csv
# 2025-03-02 18:52:04,013 [INFO] Converted all values to string in: VRA_2005_01.csv
# 2025-03-02 18:52:04,043 [INFO] Converted all values to string in: VRA_2021_02.csv
# 2025-03-02 18:52:04,061 [INFO] Converted all values to string in: VRA_2003_08.csv
# 2025-03-02 18:52:04,159 [INFO] Converted all values to string in: VRA_2013_05.csv
# 2025-03-02 18:52:04,182 [INFO] Converted all values to string in: VRA_2001_03.csv
# 2025-03-02 18:52:04,233 [INFO] Converted all values to string in: VRA_2023_05.csv
# 2025-03-02 18:52:04,278 [INFO] Converted all values to string in: VRA_2021_11.csv
# 2025-03-02 18:52:04,299 [INFO] Converted all values to string in: VRA_2008_02.csv
# 2025-03-02 18:52:04,321 [INFO] Converted all values to string in: VRA_2000_08.csv
# 2025-03-02 18:52:04,340 [INFO] Converted all values to string in: VRA_2003_05.csv
# 2025-03-02 18:52:04,401 [INFO] Converted all values to string in: VRA_2018_08.csv
# 2025-03-02 18:52:04,494 [INFO] Converted all values to string in: VRA_2018_01.csv
# 2025-03-02 18:52:04,574 [INFO] Converted all values to string in: VRA_2023_12.csv
# 2025-03-02 18:52:04,614 [INFO] Converted all values to string in: VRA_2021_08.csv
# 2025-03-02 18:52:04,634 [INFO] Converted all values to string in: VRA_2009_04.csv
# 2025-03-02 18:52:04,737 [INFO] Converted all values to string in: VRA_2015_08.csv
# 2025-03-02 18:52:04,759 [INFO] Converted all values to string in: VRA_2000_07.csv
# 2025-03-02 18:52:04,780 [INFO] Converted all values to string in: VRA_2007_05.csv
# 2025-03-02 18:52:04,888 [INFO] Converted all values to string in: VRA_2012_06.csv
# 2025-03-02 18:52:04,989 [INFO] Converted all values to string in: VRA_2011_07.csv
# 2025-03-02 18:52:05,084 [INFO] Converted all values to string in: VRA_2014_02.csv
# 2025-03-02 18:52:05,106 [INFO] Converted all values to string in: VRA_2002_12.csv
# 2025-03-02 18:52:05,142 [INFO] Converted all values to string in: VRA_2021_09.csv
# 2025-03-02 18:52:05,173 [INFO] Converted all values to string in: VRA_2021_05.csv
# 2025-03-02 18:52:05,193 [INFO] Converted all values to string in: VRA_2006_12.csv
# 2025-03-02 18:52:05,288 [INFO] Converted all values to string in: VRA_2015_05.csv
# 2025-03-02 18:52:05,380 [INFO] Converted all values to string in: VRA_2016_03.csv
# 2025-03-02 18:52:05,453 [INFO] Converted all values to string in: VRA_2018_07.csv
# 2025-03-02 18:52:05,556 [INFO] Converted all values to string in: VRA_2013_12.csv
# 2025-03-02 18:52:05,579 [INFO] Converted all values to string in: VRA_2007_09.csv
# 2025-03-02 18:52:05,603 [INFO] Converted all values to string in: VRA_2009_03.csv
# 2025-03-02 18:52:05,682 [INFO] Converted all values to string in: VRA_2016_09.csv
# 2025-03-02 18:52:05,738 [INFO] Converted all values to string in: VRA_2019_08.csv
# 2025-03-02 18:52:05,758 [INFO] Converted all values to string in: VRA_2005_11.csv
# 2025-03-02 18:52:05,847 [INFO] Converted all values to string in: VRA_2013_09.csv
# 2025-03-02 18:52:05,954 [INFO] Converted all values to string in: VRA_2014_01.csv
# 2025-03-02 18:52:05,975 [INFO] Converted all values to string in: VRA_2006_09.csv
# 2025-03-02 18:52:06,074 [INFO] Converted all values to string in: VRA_2010_12.csv
# 2025-03-02 18:52:06,098 [INFO] Converted all values to string in: VRA_2008_01.csv
# 2025-03-02 18:52:06,118 [INFO] Converted all values to string in: VRA_2000_05.csv
# 2025-03-02 18:52:06,138 [INFO] Converted all values to string in: VRA_2001_11.csv
# 2025-03-02 18:52:06,157 [INFO] Converted all values to string in: VRA_2001_09.csv
# 2025-03-02 18:52:06,236 [INFO] Converted all values to string in: VRA_2024_09.csv
# 2025-03-02 18:52:06,256 [INFO] Converted all values to string in: VRA_2004_02.csv
# 2025-03-02 18:52:06,354 [INFO] Converted all values to string in: VRA_2015_12.csv
# 2025-03-02 18:52:06,441 [INFO] Converted all values to string in: VRA_2024_10.csv
# 2025-03-02 18:52:06,501 [INFO] Converted all values to string in: VRA_2023_07.csv
# 2025-03-02 18:52:06,606 [INFO] Converted all values to string in: VRA_2013_02.csv
# 2025-03-02 18:52:06,667 [INFO] Converted all values to string in: VRA_2018_10.csv
# 2025-03-02 18:52:06,728 [INFO] Converted all values to string in: VRA_2023_01.csv
# 2025-03-02 18:52:06,826 [INFO] Converted all values to string in: VRA_2011_09.csv
# 2025-03-02 18:52:06,850 [INFO] Converted all values to string in: VRA_2007_04.csv
# 2025-03-02 18:52:06,871 [INFO] Converted all values to string in: VRA_2001_05.csv
# 2025-03-02 18:52:06,943 [INFO] Converted all values to string in: VRA_2025_01.csv
# 2025-03-02 18:52:06,953 [INFO] Converted all values to string in: VRA_2020_04.csv
# 2025-03-02 18:52:07,070 [INFO] Converted all values to string in: VRA_2013_01.csv
# 2025-03-02 18:52:07,092 [INFO] Converted all values to string in: VRA_2003_02.csv
# 2025-03-02 18:52:07,179 [INFO] Converted all values to string in: VRA_2024_07.csv
# 2025-03-02 18:52:07,289 [INFO] Converted all values to string in: VRA_2015_01.csv
# 2025-03-02 18:52:07,391 [INFO] Converted all values to string in: VRA_2013_08.csv
# 2025-03-02 18:52:07,447 [INFO] Converted all values to string in: VRA_2024_06.csv
# 2025-03-02 18:52:07,533 [INFO] Converted all values to string in: VRA_2017_06.csv
# 2025-03-02 18:52:07,631 [INFO] Converted all values to string in: VRA_2016_02.csv
# 2025-03-02 18:52:07,693 [INFO] Converted all values to string in: VRA_2019_09.csv
# 2025-03-02 18:52:07,715 [INFO] Converted all values to string in: VRA_2005_10.csv
# 2025-03-02 18:52:07,823 [INFO] Converted all values to string in: VRA_2015_03.csv
# 2025-03-02 18:52:07,882 [INFO] Converted all values to string in: VRA_2018_11.csv
# 2025-03-02 18:52:07,905 [INFO] Converted all values to string in: VRA_2002_07.csv
# 2025-03-02 18:52:07,958 [INFO] Converted all values to string in: VRA_2023_06.csv
# 2025-03-02 18:52:08,018 [INFO] Converted all values to string in: VRA_2018_06.csv
# 2025-03-02 18:52:08,038 [INFO] Converted all values to string in: VRA_2006_04.csv
# 2025-03-02 18:52:08,129 [INFO] Converted all values to string in: VRA_2012_02.csv
# 2025-03-02 18:52:08,232 [INFO] Converted all values to string in: VRA_2014_04.csv
# 2025-03-02 18:52:08,254 [INFO] Converted all values to string in: VRA_2005_06.csv
# 2025-03-02 18:52:08,274 [INFO] Converted all values to string in: VRA_2001_08.csv
# 2025-03-02 18:52:08,296 [INFO] Converted all values to string in: VRA_2008_10.csv
# 2025-03-02 18:52:08,383 [INFO] Converted all values to string in: VRA_2016_04.csv
# 2025-03-02 18:52:08,472 [INFO] Converted all values to string in: VRA_2010_09.csv
# 2025-03-02 18:52:08,529 [INFO] Converted all values to string in: VRA_2018_09.csv
# 2025-03-02 18:52:08,553 [INFO] Converted all values to string in: VRA_2009_09.csv
# 2025-03-02 18:52:08,572 [INFO] Converted all values to string in: VRA_2008_07.csv
# 2025-03-02 18:52:08,659 [INFO] Converted all values to string in: VRA_2016_12.csv
# 2025-03-02 18:52:08,757 [INFO] Converted all values to string in: VRA_2015_04.csv
# 2025-03-02 18:52:08,853 [INFO] Converted all values to string in: VRA_2012_11.csv
# 2025-03-02 18:52:08,917 [INFO] Converted all values to string in: VRA_2019_12.csv
# 2025-03-02 18:52:08,940 [INFO] Converted all values to string in: VRA_2000_01.csv
# 2025-03-02 18:52:08,961 [INFO] Converted all values to string in: VRA_2009_11.csv
# 2025-03-02 18:52:09,059 [INFO] Converted all values to string in: VRA_2014_10.csv
# 2025-03-02 18:52:09,083 [INFO] Converted all values to string in: VRA_2008_09.csv
# 2025-03-02 18:52:09,183 [INFO] Converted all values to string in: VRA_2012_10.csv
# 2025-03-02 18:52:09,234 [INFO] Converted all values to string in: VRA_2022_02.csv
# 2025-03-02 18:52:09,255 [INFO] Converted all values to string in: VRA_2006_06.csv
# 2025-03-02 18:52:09,359 [INFO] Converted all values to string in: VRA_2012_12.csv
# 2025-03-02 18:52:09,387 [INFO] Converted all values to string in: VRA_2007_10.csv
# 2025-03-02 18:52:09,405 [INFO] Converted all values to string in: VRA_2004_07.csv
# 2025-03-02 18:52:09,423 [INFO] Converted all values to string in: VRA_2005_07.csv
# 2025-03-02 18:52:09,441 [INFO] Converted all values to string in: VRA_2004_12.csv
# 2025-03-02 18:52:09,461 [INFO] Converted all values to string in: VRA_2007_08.csv
# 2025-03-02 18:52:09,508 [INFO] Converted all values to string in: VRA_2022_06.csv
# 2025-03-02 18:52:09,602 [INFO] Converted all values to string in: VRA_2010_01.csv
# 2025-03-02 18:52:09,624 [INFO] Converted all values to string in: VRA_2002_04.csv
# 2025-03-02 18:52:09,641 [INFO] Converted all values to string in: VRA_2004_06.csv
# 2025-03-02 18:52:09,658 [INFO] Converted all values to string in: VRA_2004_03.csv
# 2025-03-02 18:52:09,661 [INFO] Forcing all values to string completed.
